# %% [markdown]
# ## Network Traffic Dataset for malicious attack

# %% [markdown]
# This dataset of network traffic flow is generated by CICFlowMeter, indicate whether the traffic is malicious attack (Bot) or not (Benign).
# CICFlowMeter - network traffic flow generator generates 69 statistical features such as Duration, Number of packets, Number of bytes, Length of packets, etc are also calculated separately in the forward and reverse direction.
# The output of the application is the CSV file format with two columns labeled for each flow, namely Benign or Bot. The dataset has been organized per day, for each day the raw data including the network traffic (Pcaps) and event logs (windows and Ubuntu event Logs) per machine are recorded. Download the dataset from the below wget command line provided and rename it as Network_Traffic.csv

# %%
! wget https://cse-cic-ids2018.s3.ca-central-1.amazonaws.com/Processed+Traffic+Data+for+ML+Algorithms/Friday-02-03-2018_TrafficForML_CICFlowMeter.csv

# %% [markdown]
# ## Create requirements.txt

# %%
# %%writefile requirements.txt
# cloudpickle==1.1.1
# pandas
# scikit-learn==0.22.2
# imblearn
# joblib
# numpy
# seldon-core
# tornado>=6.0.3
# tensorflow==1.13.1
# keras==2.2.4
# google-cloud-storage
# kubeflow-tfjob
# azure==4.0.0
# kubeflow-fairing
# kubernetes==10.0.1
# Out:
# Writing requirements.txt

# %% [markdown]
# ## Install the packages listed in requirements.txt using pip

# %%
# !pip install --user -r requirements.txt
# Out:
# Requirement already satisfied: cloudpickle==1.1.1 in ./.local/lib/python3.6/site-packages (from -r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: pandas in ./.local/lib/python3.6/site-packages (from -r requirements.txt (line 2)) (1.0.3)
# Requirement already satisfied: scikit-learn==0.22.2 in ./.local/lib/python3.6/site-packages (from -r requirements.txt (line 3)) (0.22.2)
# Requirement already satisfied: imblearn in ./.local/lib/python3.6/site-packages (from -r requirements.txt (line 4)) (0.0)
# Requirement already satisfied: joblib in ./.local/lib/python3.6/site-packages (from -r requirements.txt (line 5)) (0.14.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 6)) (1.18.1)
# Requirement already satisfied: seldon-core in ./.local/lib/python3.6/site-packages (from -r requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: tornado>=6.0.3 in ./.local/lib/python3.6/site-packages (from -r requirements.txt (line 8)) (6.0.4)
# Requirement already satisfied: tensorflow==1.13.1 in ./.local/lib/python3.6/site-packages (from -r requirements.txt (line 9)) (1.13.1)
# Requirement already satisfied: keras==2.2.4 in ./.local/lib/python3.6/site-packages (from -r requirements.txt (line 10)) (2.2.4)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 11)) (1.25.0)
# Requirement already satisfied: kubeflow-tfjob in ./.local/lib/python3.6/site-packages (from -r requirements.txt (line 12)) (0.1.3)
# Requirement already satisfied: azure==4.0.0 in ./.local/lib/python3.6/site-packages (from -r requirements.txt (line 13)) (4.0.0)
# Requirement already satisfied: kubeflow-fairing in ./.local/lib/python3.6/site-packages (from -r requirements.txt (line 14)) (0.7.2)
# Requirement already satisfied: kubernetes==10.0.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 15)) (10.0.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->-r requirements.txt (line 2)) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->-r requirements.txt (line 2)) (2.8.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn==0.22.2->-r requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: imbalanced-learn in ./.local/lib/python3.6/site-packages (from imblearn->-r requirements.txt (line 4)) (0.6.2)
# Requirement already satisfied: grpcio-opentracing<1.2.0,>=1.1.4 in ./.local/lib/python3.6/site-packages (from seldon-core->-r requirements.txt (line 7)) (1.1.4)
# Requirement already satisfied: Flask-OpenTracing<1.2.0,>=1.1.0 in ./.local/lib/python3.6/site-packages (from seldon-core->-r requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: redis<4.0.0 in ./.local/lib/python3.6/site-packages (from seldon-core->-r requirements.txt (line 7)) (3.4.1)
# Requirement already satisfied: opentracing<2.3.0,>=2.2.0 in ./.local/lib/python3.6/site-packages (from seldon-core->-r requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 7)) (2.22.0)
# Requirement already satisfied: jaeger-client<4.2.0,>=4.1.0 in ./.local/lib/python3.6/site-packages (from seldon-core->-r requirements.txt (line 7)) (4.1.0)
# Requirement already satisfied: Flask-cors<4.0.0 in ./.local/lib/python3.6/site-packages (from seldon-core->-r requirements.txt (line 7)) (3.0.8)
# Requirement already satisfied: pyaml<20.0.0 in ./.local/lib/python3.6/site-packages (from seldon-core->-r requirements.txt (line 7)) (19.12.0)
# Requirement already satisfied: flatbuffers<2.0.0 in ./.local/lib/python3.6/site-packages (from seldon-core->-r requirements.txt (line 7)) (1.12)
# Requirement already satisfied: minio<6.0.0,>=4.0.9 in ./.local/lib/python3.6/site-packages (from seldon-core->-r requirements.txt (line 7)) (5.0.10)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 7)) (42.0.2)
# Requirement already satisfied: prometheus-client<0.8.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: grpcio<2.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 7)) (1.26.0)
# Requirement already satisfied: gunicorn<20.1.0,>=19.9.0 in ./.local/lib/python3.6/site-packages (from seldon-core->-r requirements.txt (line 7)) (20.0.4)
# Requirement already satisfied: Flask<2.0.0 in ./.local/lib/python3.6/site-packages (from seldon-core->-r requirements.txt (line 7)) (1.1.2)
# Requirement already satisfied: azure-storage-blob<3.0.0,>=2.0.1 in ./.local/lib/python3.6/site-packages (from seldon-core->-r requirements.txt (line 7)) (2.1.0)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.6/dist-packages (from seldon-core->-r requirements.txt (line 7)) (3.11.2)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1->-r requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: wheel>=0.26 in /usr/lib/python3/dist-packages (from tensorflow==1.13.1->-r requirements.txt (line 9)) (0.30.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1->-r requirements.txt (line 9)) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1->-r requirements.txt (line 9)) (0.8.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1->-r requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1->-r requirements.txt (line 9)) (0.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.13.1->-r requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/lib/python3/dist-packages (from tensorflow==1.13.1->-r requirements.txt (line 9)) (1.11.0)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in ./.local/lib/python3.6/site-packages (from tensorflow==1.13.1->-r requirements.txt (line 9)) (1.13.1)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in ./.local/lib/python3.6/site-packages (from tensorflow==1.13.1->-r requirements.txt (line 9)) (1.13.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4->-r requirements.txt (line 10)) (5.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4->-r requirements.txt (line 10)) (2.10.0)
# Requirement already satisfied: google-resumable-media<0.6dev,>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from google-cloud-storage->-r requirements.txt (line 11)) (0.5.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from google-cloud-storage->-r requirements.txt (line 11)) (1.11.0)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from google-cloud-storage->-r requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: table-logger>=0.3.5 in ./.local/lib/python3.6/site-packages (from kubeflow-tfjob->-r requirements.txt (line 12)) (0.3.6)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.6/dist-packages (from kubeflow-tfjob->-r requirements.txt (line 12)) (1.25.8)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.6/dist-packages (from kubeflow-tfjob->-r requirements.txt (line 12)) (2019.11.28)
# Requirement already satisfied: azure-keyvault~=1.0 in ./.local/lib/python3.6/site-packages (from azure==4.0.0->-r requirements.txt (line 13)) (1.1.0)
# Requirement already satisfied: azure-cosmosdb-table~=1.0 in ./.local/lib/python3.6/site-packages (from azure==4.0.0->-r requirements.txt (line 13)) (1.0.6)
# Requirement already satisfied: azure-loganalytics~=0.1.0 in ./.local/lib/python3.6/site-packages (from azure==4.0.0->-r requirements.txt (line 13)) (0.1.0)
# Requirement already satisfied: azure-batch~=4.1 in ./.local/lib/python3.6/site-packages (from azure==4.0.0->-r requirements.txt (line 13)) (4.1.3)
# Requirement already satisfied: azure-storage-file~=1.3 in ./.local/lib/python3.6/site-packages (from azure==4.0.0->-r requirements.txt (line 13)) (1.4.0)
# Requirement already satisfied: azure-datalake-store~=0.0.18 in ./.local/lib/python3.6/site-packages (from azure==4.0.0->-r requirements.txt (line 13)) (0.0.48)
# Requirement already satisfied: azure-graphrbac~=0.40.0 in ./.local/lib/python3.6/site-packages (from azure==4.0.0->-r requirements.txt (line 13)) (0.40.0)
# Requirement already satisfied: azure-eventgrid~=1.1 in ./.local/lib/python3.6/site-packages (from azure==4.0.0->-r requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: azure-servicebus~=0.21.1 in ./.local/lib/python3.6/site-packages (from azure==4.0.0->-r requirements.txt (line 13)) (0.21.1)
# Requirement already satisfied: azure-mgmt~=4.0 in ./.local/lib/python3.6/site-packages (from azure==4.0.0->-r requirements.txt (line 13)) (4.0.0)
# Requirement already satisfied: azure-storage-queue~=1.3 in ./.local/lib/python3.6/site-packages (from azure==4.0.0->-r requirements.txt (line 13)) (1.4.0)
# Requirement already satisfied: azure-servicemanagement-legacy~=0.20.6 in ./.local/lib/python3.6/site-packages (from azure==4.0.0->-r requirements.txt (line 13)) (0.20.6)
# Requirement already satisfied: azure-applicationinsights~=0.1.0 in ./.local/lib/python3.6/site-packages (from azure==4.0.0->-r requirements.txt (line 13)) (0.1.0)
# Requirement already satisfied: azure-servicefabric~=6.3.0.0 in ./.local/lib/python3.6/site-packages (from azure==4.0.0->-r requirements.txt (line 13)) (6.3.0.0)
# Requirement already satisfied: ibm-cos-sdk>=2.6.0 in ./.local/lib/python3.6/site-packages (from kubeflow-fairing->-r requirements.txt (line 14)) (2.6.2)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.6/dist-packages (from kubeflow-fairing->-r requirements.txt (line 14)) (0.18.2)
# Requirement already satisfied: azure-mgmt-storage>=9.0.0 in ./.local/lib/python3.6/site-packages (from kubeflow-fairing->-r requirements.txt (line 14)) (9.0.0)
# Requirement already satisfied: boto3>=1.9.0 in ./.local/lib/python3.6/site-packages (from kubeflow-fairing->-r requirements.txt (line 14)) (1.12.46)
# Requirement already satisfied: notebook>=5.6.0 in /usr/local/lib/python3.6/dist-packages (from kubeflow-fairing->-r requirements.txt (line 14)) (6.0.3)
# Requirement already satisfied: docker>=3.4.1 in /usr/local/lib/python3.6/dist-packages (from kubeflow-fairing->-r requirements.txt (line 14)) (4.1.0)
# Requirement already satisfied: google-cloud-logging>=1.13.0 in ./.local/lib/python3.6/site-packages (from kubeflow-fairing->-r requirements.txt (line 14)) (1.15.0)
# Requirement already satisfied: httplib2>=0.12.0 in /usr/local/lib/python3.6/dist-packages (from kubeflow-fairing->-r requirements.txt (line 14)) (0.17.0)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from kubeflow-fairing->-r requirements.txt (line 14)) (4.1.3)
# Requirement already satisfied: kfserving>=0.2.1.1 in ./.local/lib/python3.6/site-packages (from kubeflow-fairing->-r requirements.txt (line 14)) (0.3.0.1)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /usr/local/lib/python3.6/dist-packages (from kubeflow-fairing->-r requirements.txt (line 14)) (1.7.11)
# Requirement already satisfied: retrying>=1.3.3 in ./.local/lib/python3.6/site-packages (from kubeflow-fairing->-r requirements.txt (line 14)) (1.3.3)
# Requirement already satisfied: kubeflow-pytorchjob>=0.1.1 in ./.local/lib/python3.6/site-packages (from kubeflow-fairing->-r requirements.txt (line 14)) (0.1.3)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.6/dist-packages (from kubernetes==10.0.1->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.6/dist-packages (from kubernetes==10.0.1->-r requirements.txt (line 15)) (0.57.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->seldon-core->-r requirements.txt (line 7)) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0->seldon-core->-r requirements.txt (line 7)) (2.6)
# Requirement already satisfied: threadloop<2,>=1 in ./.local/lib/python3.6/site-packages (from jaeger-client<4.2.0,>=4.1.0->seldon-core->-r requirements.txt (line 7)) (1.0.2)
# Requirement already satisfied: thrift in ./.local/lib/python3.6/site-packages (from jaeger-client<4.2.0,>=4.1.0->seldon-core->-r requirements.txt (line 7)) (0.13.0)
# Requirement already satisfied: configparser in ./.local/lib/python3.6/site-packages (from minio<6.0.0,>=4.0.9->seldon-core->-r requirements.txt (line 7)) (5.0.0)
# Requirement already satisfied: click>=5.1 in ./.local/lib/python3.6/site-packages (from Flask<2.0.0->seldon-core->-r requirements.txt (line 7)) (7.1.1)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask<2.0.0->seldon-core->-r requirements.txt (line 7)) (0.16.1)
# Requirement already satisfied: itsdangerous>=0.24 in ./.local/lib/python3.6/site-packages (from Flask<2.0.0->seldon-core->-r requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from Flask<2.0.0->seldon-core->-r requirements.txt (line 7)) (2.11.0)
# Requirement already satisfied: azure-storage-common~=2.1 in ./.local/lib/python3.6/site-packages (from azure-storage-blob<3.0.0,>=2.0.1->seldon-core->-r requirements.txt (line 7)) (2.1.0)
# Requirement already satisfied: azure-common>=1.1.5 in ./.local/lib/python3.6/site-packages (from azure-storage-blob<3.0.0,>=2.0.1->seldon-core->-r requirements.txt (line 7)) (1.1.25)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1->-r requirements.txt (line 9)) (3.1.1)
# Requirement already satisfied: mock>=2.0.0 in ./.local/lib/python3.6/site-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow==1.13.1->-r requirements.txt (line 9)) (4.0.2)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2.0dev,>=1.9.0->google-cloud-storage->-r requirements.txt (line 11)) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2.0dev,>=1.9.0->google-cloud-storage->-r requirements.txt (line 11)) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2.0dev,>=1.9.0->google-cloud-storage->-r requirements.txt (line 11)) (4.0.0)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from google-cloud-core<2.0dev,>=1.2.0->google-cloud-storage->-r requirements.txt (line 11)) (1.16.0)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/lib/python3/dist-packages (from azure-keyvault~=1.0->azure==4.0.0->-r requirements.txt (line 13)) (2.1.4)
# Requirement already satisfied: azure-nspkg>=2.0.0 in ./.local/lib/python3.6/site-packages (from azure-keyvault~=1.0->azure==4.0.0->-r requirements.txt (line 13)) (3.0.2)
# Requirement already satisfied: msrestazure<2.0.0,>=0.4.32 in ./.local/lib/python3.6/site-packages (from azure-keyvault~=1.0->azure==4.0.0->-r requirements.txt (line 13)) (0.6.3)
# Requirement already satisfied: msrest>=0.5.0 in ./.local/lib/python3.6/site-packages (from azure-keyvault~=1.0->azure==4.0.0->-r requirements.txt (line 13)) (0.6.13)
# Requirement already satisfied: azure-cosmosdb-nspkg>=2.0.0 in ./.local/lib/python3.6/site-packages (from azure-cosmosdb-table~=1.0->azure==4.0.0->-r requirements.txt (line 13)) (2.0.2)
# Requirement already satisfied: cffi in ./.local/lib/python3.6/site-packages (from azure-datalake-store~=0.0.18->azure==4.0.0->-r requirements.txt (line 13)) (1.14.0)
# Requirement already satisfied: adal>=0.4.2 in ./.local/lib/python3.6/site-packages (from azure-datalake-store~=0.0.18->azure==4.0.0->-r requirements.txt (line 13)) (1.2.2)
# Requirement already satisfied: azure-mgmt-relay~=0.1.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.1.0)
# Requirement already satisfied: azure-mgmt-loganalytics~=0.2.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: azure-mgmt-powerbiembedded~=2.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (2.0.0)
# Requirement already satisfied: azure-mgmt-cdn~=3.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (3.1.0)
# Requirement already satisfied: azure-mgmt-applicationinsights~=0.1.1 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.1.1)
# Requirement already satisfied: azure-mgmt-datamigration~=1.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (1.0.0)
# Requirement already satisfied: azure-mgmt-dns~=2.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (2.1.0)
# Requirement already satisfied: azure-mgmt-iothub~=0.5.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.5.0)
# Requirement already satisfied: azure-mgmt-batchai~=2.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (2.0.0)
# Requirement already satisfied: azure-mgmt-eventhub~=2.1 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (2.6.0)
# Requirement already satisfied: azure-mgmt-network~=2.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (2.7.0)
# Requirement already satisfied: azure-mgmt-trafficmanager~=0.50.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.50.0)
# Requirement already satisfied: azure-mgmt-scheduler~=2.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (2.0.0)
# Requirement already satisfied: azure-mgmt-search~=2.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (2.1.0)
# Requirement already satisfied: azure-mgmt-cognitiveservices~=3.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (3.0.0)
# Requirement already satisfied: azure-mgmt-containerinstance~=1.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (1.5.0)
# Requirement already satisfied: azure-mgmt-authorization~=0.50.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.50.0)
# Requirement already satisfied: azure-mgmt-commerce~=1.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (1.0.1)
# Requirement already satisfied: azure-mgmt-marketplaceordering~=0.1.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.1.0)
# Requirement already satisfied: azure-mgmt-recoveryservicesbackup~=0.3.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.3.0)
# Requirement already satisfied: azure-mgmt-advisor~=1.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (1.0.1)
# Requirement already satisfied: azure-mgmt-recoveryservices~=0.3.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.3.0)
# Requirement already satisfied: azure-mgmt-containerservice~=4.2 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (4.4.0)
# Requirement already satisfied: azure-mgmt-resource~=2.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (2.2.0)
# Requirement already satisfied: azure-mgmt-machinelearningcompute~=0.4.1 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.4.1)
# Requirement already satisfied: azure-mgmt-containerregistry~=2.1 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (2.8.0)
# Requirement already satisfied: azure-mgmt-managementpartner~=0.1.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.1.1)
# Requirement already satisfied: azure-mgmt-sql~=0.9.1 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.9.1)
# Requirement already satisfied: azure-mgmt-devspaces~=0.1.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.1.0)
# Requirement already satisfied: azure-mgmt-iotcentral~=0.1.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.1.0)
# Requirement already satisfied: azure-mgmt-msi~=0.2.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: azure-mgmt-redis~=5.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (5.0.0)
# Requirement already satisfied: azure-mgmt-maps~=0.1.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.1.0)
# Requirement already satisfied: azure-mgmt-notificationhubs~=2.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (2.1.0)
# Requirement already satisfied: azure-mgmt-servicebus~=0.5.1 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.5.3)
# Requirement already satisfied: azure-mgmt-managementgroups~=0.1.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.1.0)
# Requirement already satisfied: azure-mgmt-consumption~=2.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (2.0.0)
# Requirement already satisfied: azure-mgmt-devtestlabs~=2.2 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (2.2.0)
# Requirement already satisfied: azure-mgmt-eventgrid~=1.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (1.0.0)
# Requirement already satisfied: azure-mgmt-subscription~=0.2.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: azure-mgmt-reservations~=0.2.1 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.2.1)
# Requirement already satisfied: azure-mgmt-servicefabric~=0.2.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: azure-mgmt-compute~=4.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (4.6.2)
# Requirement already satisfied: azure-mgmt-rdbms~=1.2 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (1.9.0)
# Requirement already satisfied: azure-mgmt-signalr~=0.1.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.1.1)
# Requirement already satisfied: azure-mgmt-billing~=0.2.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: azure-mgmt-monitor~=0.5.2 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.5.2)
# Requirement already satisfied: azure-mgmt-logic~=3.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (3.0.0)
# Requirement already satisfied: azure-mgmt-media~=1.0.0rc2 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (1.0.0)
# Requirement already satisfied: azure-mgmt-batch~=5.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (5.0.1)
# Requirement already satisfied: azure-mgmt-hanaonazure~=0.1.1 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.1.1)
# Requirement already satisfied: azure-mgmt-keyvault~=1.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (1.1.0)
# Requirement already satisfied: azure-mgmt-datalake-analytics~=0.6.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.6.0)
# Requirement already satisfied: azure-mgmt-datalake-store~=0.5.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.5.0)
# Requirement already satisfied: azure-mgmt-datafactory~=0.6.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.6.0)
# Requirement already satisfied: azure-mgmt-policyinsights~=0.1.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.1.0)
# Requirement already satisfied: azure-mgmt-iothubprovisioningservices~=0.2.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: azure-mgmt-cosmosdb~=0.4.1 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.4.1)
# Requirement already satisfied: azure-mgmt-web~=0.35.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (0.35.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in ./.local/lib/python3.6/site-packages (from ibm-cos-sdk>=2.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.9.5)
# Requirement already satisfied: ibm-cos-sdk-core==2.6.2 in ./.local/lib/python3.6/site-packages (from ibm-cos-sdk>=2.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (2.6.2)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.6.2 in ./.local/lib/python3.6/site-packages (from ibm-cos-sdk>=2.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (2.6.2)
# Requirement already satisfied: botocore<1.16.0,>=1.15.46 in ./.local/lib/python3.6/site-packages (from boto3>=1.9.0->kubeflow-fairing->-r requirements.txt (line 14)) (1.15.46)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in ./.local/lib/python3.6/site-packages (from boto3>=1.9.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.3.3)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.6/dist-packages (from notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (4.6.1)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.6/dist-packages (from notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (4.3.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.6/dist-packages (from notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (18.1.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (5.6.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (5.1.4)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.6/dist-packages (from notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.8.3)
# Requirement already satisfied: jupyter-client>=5.3.4 in /usr/local/lib/python3.6/dist-packages (from notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (5.3.4)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.6/dist-packages (from notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (5.0.4)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.4.8)
# Requirement already satisfied: argparse>=1.4.0 in ./.local/lib/python3.6/site-packages (from kfserving>=0.2.1.1->kubeflow-fairing->-r requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.7.8->kubeflow-fairing->-r requirements.txt (line 14)) (0.0.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.7.8->kubeflow-fairing->-r requirements.txt (line 14)) (3.0.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib->kubernetes==10.0.1->-r requirements.txt (line 15)) (3.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->Flask<2.0.0->seldon-core->-r requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0.0dev,>=1.16.0->google-cloud-core<2.0dev,>=1.2.0->google-cloud-storage->-r requirements.txt (line 11)) (1.51.0)
# Requirement already satisfied: isodate>=0.6.0 in ./.local/lib/python3.6/site-packages (from msrest>=0.5.0->azure-keyvault~=1.0->azure==4.0.0->-r requirements.txt (line 13)) (0.6.0)
# Requirement already satisfied: pycparser in ./.local/lib/python3.6/site-packages (from cffi->azure-datalake-store~=0.0.18->azure==4.0.0->-r requirements.txt (line 13)) (2.20)
# Requirement already satisfied: PyJWT>=1.0.0 in ./.local/lib/python3.6/site-packages (from adal>=0.4.2->azure-datalake-store~=0.0.18->azure==4.0.0->-r requirements.txt (line 13)) (1.7.1)
# Requirement already satisfied: azure-mgmt-nspkg>=2.0.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt-relay~=0.1.0->azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (3.0.2)
# Requirement already satisfied: azure-mgmt-datalake-nspkg>=2.0.0 in ./.local/lib/python3.6/site-packages (from azure-mgmt-datalake-analytics~=0.6.0->azure-mgmt~=4.0->azure==4.0.0->-r requirements.txt (line 13)) (3.0.1)
# Requirement already satisfied: docutils>=0.10 in ./.local/lib/python3.6/site-packages (from ibm-cos-sdk-core==2.6.2->ibm-cos-sdk>=2.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.15.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2.1->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (4.4.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (2.5.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (3.1.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.4.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (1.4.2)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (7.11.1)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /usr/local/lib/python3.6/dist-packages (from terminado>=0.8.1->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.6.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (3.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.5.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.6/dist-packages (from ipython>=5.0.0->ipykernel->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=5.0.0->ipykernel->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=5.0.0->ipykernel->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.0.0->ipykernel->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (2.0.10)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.0.0->ipykernel->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.15.7)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (19.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.1.8)
# Requirement already satisfied: parso>=0.5.2 in /usr/local/lib/python3.6/dist-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (0.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.6.0->kubeflow-fairing->-r requirements.txt (line 14)) (2.1.0)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ## Restart the Kernal

# %%
from IPython.display import display_html
display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %% [markdown]
# # Configure docker credentials
#
# Get your docker registry user and password encoded in base64
#
# echo -n USER:PASSWORD | base64
#
# Create a config.json file with your Docker registry url and the previous generated base64 string

# %%
# !echo -n USER:PASSWORD | base64

# %%
# %%writefile config.json
# {
#     "auths": {
#         "https://index.docker.io/v1/": {
#             "auth": "<<Provide previous generated base64 string>>"
#         }
#     }
# }
# Out:
# Writing config.json

# %% [markdown]
# ### Create a config-map in the namespace you're using with the docker config

# %%
# !kubectl create --namespace anonymous configmap docker-config --from-file=./config.json
# Out:
# configmap/docker-config created

# %% [markdown]
# ## Dockerfile
# Update dockerfile base image with tensorflow-gpu image if device type is GPU

# %%
device_type="gpu"  #Provide cpu or gpu
if device_type=="gpu":
    # !sed -i "s/py3/gpu-py3/g" Dockerfile
    # !cat Dockerfile
else:
    # !cat Dockerfile
# Out:
# FROM tensorflow/tensorflow:1.14.0-gpu-py3
# RUN pip install -U scikit-learn
# RUN pip install keras pandas imblearn
# ADD network_model.py  /opt/network_model.py
# ADD Network_Traffic.csv /opt/Network_Traffic.csv
# RUN chmod +x /opt/network_model.py  /opt/Network_Traffic.csv
# WORKDIR /opt/
# RUN mkdir -p /mnt/Model_Network
# CMD python network_model.py

# %% [markdown]
# ## Import Libraries

# %%
from kubernetes.client import V1PodTemplateSpec
from kubernetes.client import V1ObjectMeta
from kubernetes.client import V1PodSpec
from kubernetes.client import V1Container
from kubernetes.client import V1VolumeMount
from kubernetes.client import V1Volume
from kubernetes.client import V1PersistentVolumeClaimVolumeSource
from kubernetes.client import V1ResourceRequirements

from kubeflow.tfjob import constants
from kubeflow.tfjob import utils
from kubeflow.tfjob import V1ReplicaSpec
from kubeflow.tfjob import V1TFJob
from kubeflow.tfjob import V1TFJobSpec
from kubeflow.tfjob import TFJobClient


import time
import re, os
import tensorflow as tf
import pandas as pd
import numpy as np
import logging
import sys
import importlib
# Out:
# /home/jovyan/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jovyan/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jovyan/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/jovyan/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/jovyan/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/jovyan/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## Set up Kubeflow Fairing for training and predictions on On-premise
# Import the fairing library and configure the onprem environment that your training or prediction job will run in.

# %%
from kubernetes import client as k8s_client
from kubernetes.client import rest as k8s_rest
from kubernetes import config as k8s_config
from kubernetes.client.rest import ApiException

from kubeflow import fairing   
from kubeflow.fairing import utils as fairing_utils
from kubeflow.fairing import TrainJob
from kubeflow.fairing.preprocessors.function import FunctionPreProcessor
from kubeflow.fairing.preprocessors import base as base_preprocessor
from kubeflow.fairing.builders.cluster.cluster import ClusterBuilder

from kubeflow.fairing.cloud.k8s import MinioUploader
from kubeflow.fairing.builders.cluster.minio_context import MinioContextSource
from kubeflow.fairing import PredictionEndpoint
from kubeflow.fairing.kubernetes.utils import mounting_pvc
from kubeflow.fairing.kubernetes.utils import mounting_pvc

BackendClass = getattr(importlib.import_module('kubeflow.fairing.backends'), "KubernetesBackend")
namespace = fairing_utils.get_current_k8s_namespace()
print("Namespace : %s"%namespace)
# Out:
# Namespace : anonymous

# %% [markdown]
# ## Get minio-service cluster IP to upload docker build context
# #### Set DOCKER_REGISTRY
# The DOCKER_REGISTRY variable is used to push the newly built image.
# Please change the variable to the registry for which you've configured credentials.

# %%
DOCKER_REGISTRY = "edward1723"

k8s_config.load_incluster_config()
api_client = k8s_client.CoreV1Api()
minio_service_endpoint = None

try:
    minio_service_endpoint = api_client.read_namespaced_service(name='minio-service', namespace='kubeflow').spec.cluster_ip
except ApiException as e:
    if e.status == 403:
        logging.warning(f"The service account doesn't have sufficient privileges "
                      f"to get the kubeflow minio-service. "
                      f"You will have to manually enter the minio cluster-ip. "
                      f"To make this function work ask someone with cluster "
                      f"priveleges to create an appropriate "
                      f"clusterrolebinding by running a command.\n"
                      f"kubectl create --namespace=kubeflow rolebinding "
                       "--clusterrole=kubeflow-view "
                       "--serviceaccount=${NAMESPACE}:default-editor "
                       "${NAMESPACE}-minio-view")
        logging.error("API access denied with reason: {e.reason}")

s3_endpoint = minio_service_endpoint
minio_endpoint = "http://"+s3_endpoint+":9000"
minio_username = "minio"
minio_key = "minio123"
minio_region = "us-east-1"
print(minio_endpoint)


minio_uploader = MinioUploader(endpoint_url=minio_endpoint, minio_secret=minio_username, minio_secret_key=minio_key, region_name=minio_region)
minio_context_source = MinioContextSource(endpoint_url=minio_endpoint, minio_secret=minio_username, minio_secret_key=minio_key, region_name=minio_region)
# Out:
# http://10.98.188.38:9000

# %% [markdown]
# ## Build docker image
#
# Note: Upload dataset, Dockerfile, and network_model.py into notebook

# %%
#output_map is a map of extra files to add to the notebook.
# It is a map from source location to the location inside the context.
output_map= {
    "Dockerfile": "Dockerfile", #Dockerfile
    "network_model.py":"network_model.py",
    "Network_Traffic.csv": "Network_Traffic.csv"
}
preprocessor = base_preprocessor.BasePreProcessor(output_map=output_map)

preprocessor.preprocess()
builder = ClusterBuilder(registry=DOCKER_REGISTRY, preprocessor=preprocessor, context_source=minio_context_source)

builder.build()
# Out:
# Building image using cluster builder.
# Creating docker context: /tmp/fairing_context_5vaiaitz
# /tmp/fairing_dockerfile_38wtz9rv already exists in Fairing context, skipping...
# Waiting for fairing-builder-dkfzh-tdf9h to start...
# Waiting for fairing-builder-dkfzh-tdf9h to start...
# Waiting for fairing-builder-dkfzh-tdf9h to start...
# Waiting for fairing-builder-dkfzh-tdf9h to start...
# Pod started running True
# INFO[0003] Resolved base name tensorflow/tensorflow:1.14.0-gpu-py3 to tensorflow/tensorflow:1.14.0-gpu-py3
# INFO[0003] Resolved base name tensorflow/tensorflow:1.14.0-gpu-py3 to tensorflow/tensorflow:1.14.0-gpu-py3
# INFO[0003] Downloading base image tensorflow/tensorflow:1.14.0-gpu-py3
# INFO[0004] Error while retrieving image from cache: getting file info: stat /cache/sha256:e72e66b3dcb9c9e8f4e5703965ae1466b23fe8cad59e1c92c6e9fa58f8d81dc8: no such file or directory
# INFO[0004] Downloading base image tensorflow/tensorflow:1.14.0-gpu-py3
# INFO[0005] Built cross stage deps: map[]
# INFO[0005] Downloading base image tensorflow/tensorflow:1.14.0-gpu-py3
# INFO[0006] Error while retrieving image from cache: getting file info: stat /cache/sha256:e72e66b3dcb9c9e8f4e5703965ae1466b23fe8cad59e1c92c6e9fa58f8d81dc8: no such file or directory
# INFO[0006] Downloading base image tensorflow/tensorflow:1.14.0-gpu-py3
# INFO[0007] Unpacking rootfs as cmd RUN pip install -U scikit-learn requires it.
# INFO[0058] Taking snapshot of full filesystem...
# INFO[0076] RUN pip install -U scikit-learn
# INFO[0076] cmd: /bin/bash
# INFO[0076] args: [-c pip install -U scikit-learn]
# Collecting scikit-learn
#   Downloading https://files.pythonhosted.org/packages/5e/d8/312e03adf4c78663e17d802fe2440072376fee46cada1404f1727ed77a32/scikit_learn-0.22.2.post1-cp36-cp36m-manylinux1_x86_64.whl (7.1MB)
# Collecting scipy>=0.17.0 (from scikit-learn)
#   Downloading https://files.pythonhosted.org/packages/dc/29/162476fd44203116e7980cfbd9352eef9db37c49445d1fec35509022f6aa/scipy-1.4.1-cp36-cp36m-manylinux1_x86_64.whl (26.1MB)
# Collecting joblib>=0.11 (from scikit-learn)
#   Downloading https://files.pythonhosted.org/packages/28/5c/cf6a2b65a321c4a209efcdf64c2689efae2cb62661f8f6f4bb28547cf1bf/joblib-0.14.1-py2.py3-none-any.whl (294kB)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.16.4)
# Installing collected packages: scipy, joblib, scikit-learn
# Successfully installed joblib-0.14.1 scikit-learn-0.22.2.post1 scipy-1.4.1
# WARNING: You are using pip version 19.1.1, however version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# INFO[0082] Taking snapshot of full filesystem...
# INFO[0092] RUN pip install keras pandas imblearn
# INFO[0092] cmd: /bin/bash
# INFO[0092] args: [-c pip install keras pandas imblearn]
# Collecting keras
#   Downloading https://files.pythonhosted.org/packages/ad/fd/6bfe87920d7f4fd475acd28500a42482b6b84479832bdc0fe9e589a60ceb/Keras-2.3.1-py2.py3-none-any.whl (377kB)
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/bb/71/8f53bdbcbc67c912b888b40def255767e475402e9df64050019149b1a943/pandas-1.0.3-cp36-cp36m-manylinux1_x86_64.whl (10.0MB)
# Collecting imblearn
#   Downloading https://files.pythonhosted.org/packages/81/a7/4179e6ebfd654bd0eac0b9c06125b8b4c96a9d0a8ff9e9507eb2a26d2d7e/imblearn-0.0-py2.py3-none-any.whl
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras) (1.1.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from keras) (1.11.0)
# Collecting pyyaml (from keras)
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.16.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.9.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.8)
# Collecting pytz>=2017.2 (from pandas)
#   Downloading https://files.pythonhosted.org/packages/4f/a4/879454d49688e2fad93e59d7d4efda580b783c745fd2ec2a3adf87b0808d/pytz-2020.1-py2.py3-none-any.whl (510kB)
# Collecting python-dateutil>=2.6.1 (from pandas)
#   Downloading https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl (227kB)
# Collecting imbalanced-learn (from imblearn)
#   Downloading https://files.pythonhosted.org/packages/c8/73/36a13185c2acff44d601dc6107b5347e075561a49e15ddd4e69988414c3e/imbalanced_learn-0.6.2-py3-none-any.whl (163kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from imbalanced-learn->imblearn) (0.14.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.6/dist-packages (from imbalanced-learn->imblearn) (0.22.2.post1)
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py): started
#   Building wheel for pyyaml (setup.py): finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# Successfully built pyyaml
# Installing collected packages: pyyaml, keras, pytz, python-dateutil, pandas, imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.6.2 imblearn-0.0 keras-2.3.1 pandas-1.0.3 python-dateutil-2.8.1 pytz-2020.1 pyyaml-5.3.1
# WARNING: You are using pip version 19.1.1, however version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# INFO[0097] Taking snapshot of full filesystem...
# INFO[0104] Using files from context: [/kaniko/buildcontext/network_model.py]
# INFO[0104] ADD network_model.py  /opt/network_model.py
# INFO[0104] Taking snapshot of files...
# INFO[0104] Using files from context: [/kaniko/buildcontext/Network_Traffic.csv]
# INFO[0105] ADD Network_Traffic.csv /opt/Network_Traffic.csv
# INFO[0106] Taking snapshot of files...
# INFO[0121] RUN chmod +x /opt/network_model.py  /opt/Network_Traffic.csv
# INFO[0121] cmd: /bin/bash
# INFO[0121] args: [-c chmod +x /opt/network_model.py  /opt/Network_Traffic.csv]
# INFO[0121] Taking snapshot of full filesystem...
# INFO[0140] WORKDIR /opt/
# INFO[0140] cmd: workdir
# INFO[0140] Changed working directory to /opt
# INFO[0140] RUN mkdir -p /mnt/Model_Network
# INFO[0140] cmd: /bin/bash
# INFO[0140] args: [-c mkdir -p /mnt/Model_Network]
# INFO[0140] Taking snapshot of full filesystem...
# INFO[0144] CMD python network_model.py

# %%
builder.image_tag
# Out:
# 'edward1723/fairing-job:FBD61A65'

# %% [markdown]
# ## Define TFJob Class to create training job

# %%
tfjob_name="network-fairing-tfjob"
class Tfjob(object):

    def get_tfjob_params(self):
    
        #Defining a Volume Mount
        volume_mount = V1VolumeMount(name="nfsvolume", mount_path="/mnt/Model_Network")

        #Defining a Persistent Volume Claim
        persistent_vol_claim = V1PersistentVolumeClaimVolumeSource(claim_name="nfs1")

        #Defining a Volume
        volume = V1Volume(name="nfsvolume", persistent_volume_claim=persistent_vol_claim)
        
        if device_type=="gpu":
            #Defining a Container
            container = V1Container(
                name="tensorflow",            
                image=builder.image_tag,
                volume_mounts=[volume_mount],
                resources=V1ResourceRequirements(limits={"nvidia.com/gpu": 1})
            )
        else:
            #Defining a Container
            container = V1Container(
                name="tensorflow",            
                image=builder.image_tag,
                volume_mounts=[volume_mount]
            )
        
        return (volume_mount, persistent_vol_claim, volume, container)
        
    def get_tfjob_nodes(self):
    
        params = self.get_tfjob_params()

        #Defining a Master
        master = V1ReplicaSpec(replicas=1,
                               restart_policy="Never",
                               template=V1PodTemplateSpec(spec=V1PodSpec(
                                                    containers=[params[3]],
                                                    volumes=[params[2]])))
        
        #Defining Worker Spec
        worker = V1ReplicaSpec(replicas=1,
                               restart_policy="Never",
                               template=V1PodTemplateSpec(spec=V1PodSpec(
                                                    containers=[params[3]],
                                                    volumes=[params[2]],
                                                    
                               )))
        
        #Defining Parameter server(PS) Spec
        ps = V1ReplicaSpec(replicas=1,
                               restart_policy="Never",
                               template=V1PodTemplateSpec(spec=V1PodSpec(
                                                    containers=[params[3]],
                                                    volumes=[params[2]])))
        
        return (master,worker,ps)
    
    def create_tfjob(self):
        
        tfjob_node_spec = self.get_tfjob_nodes()
        
        #Defining TFJob
        tfjob = V1TFJob(
            api_version="kubeflow.org/v1",
            kind="TFJob",
            metadata=V1ObjectMeta(name=tfjob_name,namespace=namespace),
            spec=V1TFJobSpec(
                clean_pod_policy="None",
                tf_replica_specs={"PS":tfjob_node_spec[2],"Worker": tfjob_node_spec[1],"Master":tfjob_node_spec[0]}
            )
        )
        
        #Creating TFJob
        tfjob_client = TFJobClient()
        tfjob_client.create(tfjob, namespace=namespace)

# %% [markdown]
# ## Define Network class to be used by Kubeflow fairing
# ## ( Must necessarily contain train() and predict() methods)

# %%
class NetworkServe(object):
    
    def __init__(self):
        self.model=None
        
    def train(self):
        
        Tfjob().create_tfjob()
        
    def predict(self,X,feature_names=None):
        
        feature_col=['BwdIATMean', 'BwdIATTot', 'BwdPktLenMax', 'BwdPktLenMean', 'FlowDuration', 'FlowIATMean', 'FlowIATStd', 'FwdPSHFlags', 'FwdSegSizeMin', 'InitBwdWinByts']
        model_input1=tf.train.Example()
        for i in range(len(X)):
            model_input1.features.feature[feature_col[i]].float_list.value.append(X[i])
            
        path=os.path.join(os.getcwd(), "/mnt/Model_Network")
        for dir in os.listdir(path):
            if re.match('[0-9]',dir):
                exported_path=os.path.join(path,dir)
                break
        
        # Open a Session to predict
        with tf.Session() as sess:
         tf.saved_model.loader.load(sess, [tf.saved_model.tag_constants.SERVING], exported_path)
         model_input =model_input1
         
         predictor= tf.contrib.predictor.from_saved_model(exported_path,signature_def_key='predict')
         input_tensor=tf.get_default_graph().get_tensor_by_name("input_example_tensor:0")
            
         model_input=model_input.SerializeToString()
         output_dict= predictor({"examples":[model_input]})
        sess.close()
        
        response = output_dict.items()
        print(response)
        response1 = output_dict['class_ids']
        return response1

# %% [markdown]
# ## Train Network model remotely on Kubeflow
# Kubeflow Fairing packages the NetworkServe class, the training data, and the training job's software prerequisites as a Docker image. Then Kubeflow Fairing deploys and runs the training job on kubeflow.

# %%
train_job = TrainJob(NetworkServe, input_files=["Network_Traffic.csv", "requirements.txt"],
                     pod_spec_mutators = [mounting_pvc(pvc_name="nfs1", pvc_mount_path="/mnt/Model_Network")],
                     docker_registry=DOCKER_REGISTRY, backend=BackendClass(build_context_source=minio_context_source))
train_job.submit()
# Out:
# Using default base docker image: registry.hub.docker.com/library/python:3.6.9
# Using builder: <class 'kubeflow.fairing.builders.cluster.cluster.ClusterBuilder'>
# Building the docker image.
# Building image using cluster builder.
# /home/jovyan/.local/lib/python3.6/site-packages/kubeflow/fairing/__init__.py already exists in Fairing context, skipping...
# Creating docker context: /tmp/fairing_context_1t205qfk
# /home/jovyan/.local/lib/python3.6/site-packages/kubeflow/fairing/__init__.py already exists in Fairing context, skipping...
# Waiting for fairing-builder-49klw-q2rhg to start...
# Waiting for fairing-builder-49klw-q2rhg to start...
# Waiting for fairing-builder-49klw-q2rhg to start...
# Waiting for fairing-builder-49klw-q2rhg to start...
# Pod started running True
# INFO[0003] Resolved base name registry.hub.docker.com/library/python:3.6.9 to registry.hub.docker.com/library/python:3.6.9
# INFO[0003] Resolved base name registry.hub.docker.com/library/python:3.6.9 to registry.hub.docker.com/library/python:3.6.9
# INFO[0003] Downloading base image registry.hub.docker.com/library/python:3.6.9
# INFO[0004] Error while retrieving image from cache: getting file info: stat /cache/sha256:036d4ab50fa49df89e746cf1b5369c88db46e8af2fbd08531788e7d920e9a491: no such file or directory
# INFO[0004] Downloading base image registry.hub.docker.com/library/python:3.6.9
# INFO[0005] Built cross stage deps: map[]
# INFO[0005] Downloading base image registry.hub.docker.com/library/python:3.6.9
# INFO[0006] Error while retrieving image from cache: getting file info: stat /cache/sha256:036d4ab50fa49df89e746cf1b5369c88db46e8af2fbd08531788e7d920e9a491: no such file or directory
# INFO[0006] Downloading base image registry.hub.docker.com/library/python:3.6.9
# INFO[0007] Unpacking rootfs as cmd COPY /app//requirements.txt /app/ requires it.
# INFO[0023] Taking snapshot of full filesystem...
# INFO[0030] WORKDIR /app/
# INFO[0030] cmd: workdir
# INFO[0030] Changed working directory to /app/
# INFO[0030] Creating directory /app/
# INFO[0030] Taking snapshot of files...
# INFO[0030] ENV FAIRING_RUNTIME 1
# INFO[0030] Using files from context: [/kaniko/buildcontext/app/requirements.txt]
# INFO[0030] COPY /app//requirements.txt /app/
# INFO[0030] Taking snapshot of files...
# INFO[0030] RUN if [ -e requirements.txt ];then pip install --no-cache -r requirements.txt; fi
# INFO[0030] cmd: /bin/sh
# INFO[0030] args: [-c if [ -e requirements.txt ];then pip install --no-cache -r requirements.txt; fi]
# Collecting cloudpickle==1.1.1
#   Downloading https://files.pythonhosted.org/packages/24/fb/4f92f8c0f40a0d728b4f3d5ec5ff84353e705d8ff5e3e447620ea98b06bd/cloudpickle-1.1.1-py2.py3-none-any.whl
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/bb/71/8f53bdbcbc67c912b888b40def255767e475402e9df64050019149b1a943/pandas-1.0.3-cp36-cp36m-manylinux1_x86_64.whl (10.0MB)
# Collecting scikit-learn==0.22.2
#   Downloading https://files.pythonhosted.org/packages/e1/7f/366dcba1ba076a88a50bea732dbc033c0c5bbf7876010e6edc67948579d5/scikit_learn-0.22.2-cp36-cp36m-manylinux1_x86_64.whl (7.1MB)
# Collecting imblearn
#   Downloading https://files.pythonhosted.org/packages/81/a7/4179e6ebfd654bd0eac0b9c06125b8b4c96a9d0a8ff9e9507eb2a26d2d7e/imblearn-0.0-py2.py3-none-any.whl
# Collecting joblib
#   Downloading https://files.pythonhosted.org/packages/28/5c/cf6a2b65a321c4a209efcdf64c2689efae2cb62661f8f6f4bb28547cf1bf/joblib-0.14.1-py2.py3-none-any.whl (294kB)
# Collecting numpy
#   Downloading https://files.pythonhosted.org/packages/3d/fc/4763e5f17ac6e7e7d55f377cde859ca1c5d5ac624441ab45315bc578aa9e/numpy-1.18.3-cp36-cp36m-manylinux1_x86_64.whl (20.2MB)
# Collecting seldon-core
#   Downloading https://files.pythonhosted.org/packages/a5/a5/81f818dc216fa9a43aa195ac3d0cfaa9a7991707161b9faf8bc0dbe5022c/seldon_core-1.1.0-py3-none-any.whl (94kB)
# Collecting tornado>=6.0.3
#   Downloading https://files.pythonhosted.org/packages/95/84/119a46d494f008969bf0c775cb2c6b3579d3c4cc1bb1b41a022aa93ee242/tornado-6.0.4.tar.gz (496kB)
# Collecting tensorflow==1.13.1
#   Downloading https://files.pythonhosted.org/packages/77/63/a9fa76de8dffe7455304c4ed635be4aa9c0bacef6e0633d87d5f54530c5c/tensorflow-1.13.1-cp36-cp36m-manylinux1_x86_64.whl (92.5MB)
# Collecting keras==2.2.4
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
# Collecting google-cloud-storage
#   Downloading https://files.pythonhosted.org/packages/85/47/c3ab1b34d2448de71a39f64534b4fb5bb76ed5694370a20a45627de7372d/google_cloud_storage-1.28.0-py2.py3-none-any.whl (80kB)
# Collecting kubeflow-tfjob
#   Downloading https://files.pythonhosted.org/packages/67/09/ae7e4a13cf68ed4a99b050b798611d27744b8a99e674e16098f15609c6ff/kubeflow_tfjob-0.1.3-py3-none-any.whl (46kB)
# Collecting azure==4.0.0
#   Downloading https://files.pythonhosted.org/packages/5a/5e/f94bd8091ab0ccc68ee902e188d4e8cd3b38dc77155a1c187cbf4767d0e4/azure-4.0.0-py2.py3-none-any.whl
# Collecting kubeflow-fairing
#   Downloading https://files.pythonhosted.org/packages/d6/69/7910a26ad3f4647988ab2e415b18a50899aa78d05daf8975aa3722308c82/kubeflow_fairing-0.7.2-py3-none-any.whl (160kB)
# Collecting kubernetes==10.0.1
#   Downloading https://files.pythonhosted.org/packages/6e/fc/2cab119f679648b348b8940de0dd744a1f0ee99c690aa2ef6072f050816c/kubernetes-10.0.1-py2.py3-none-any.whl (1.5MB)
# Collecting python-dateutil>=2.6.1
#   Downloading https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl (227kB)
# Collecting pytz>=2017.2
#   Downloading https://files.pythonhosted.org/packages/4f/a4/879454d49688e2fad93e59d7d4efda580b783c745fd2ec2a3adf87b0808d/pytz-2020.1-py2.py3-none-any.whl (510kB)
# Collecting scipy>=0.17.0
#   Downloading https://files.pythonhosted.org/packages/dc/29/162476fd44203116e7980cfbd9352eef9db37c49445d1fec35509022f6aa/scipy-1.4.1-cp36-cp36m-manylinux1_x86_64.whl (26.1MB)
# Collecting imbalanced-learn
#   Downloading https://files.pythonhosted.org/packages/c8/73/36a13185c2acff44d601dc6107b5347e075561a49e15ddd4e69988414c3e/imbalanced_learn-0.6.2-py3-none-any.whl (163kB)
# Collecting prometheus-client<0.8.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/b3/23/41a5a24b502d35a4ad50a5bb7202a5e1d9a0364d0c12f56db3dbf7aca76d/prometheus_client-0.7.1.tar.gz
# Collecting grpcio-opentracing<1.2.0,>=1.1.4
#   Downloading https://files.pythonhosted.org/packages/db/82/2fcad380697c3dab25de76ee590bcab3eb9bbfb4add916044d7e83ec2b10/grpcio_opentracing-1.1.4-py3-none-any.whl
# Collecting gunicorn<20.1.0,>=19.9.0
#   Downloading https://files.pythonhosted.org/packages/69/ca/926f7cd3a2014b16870086b2d0fdc84a9e49473c68a8dff8b57f7c156f43/gunicorn-20.0.4-py2.py3-none-any.whl (77kB)
# Collecting jaeger-client<4.2.0,>=4.1.0
#   Downloading https://files.pythonhosted.org/packages/f1/da/569a4f1bc3d0c412c7f903053f09ef62fa10949374ca90bc852b22dd3860/jaeger-client-4.1.0.tar.gz (80kB)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/site-packages (from seldon-core->-r requirements.txt (line 7)) (41.6.0)
# Collecting minio<6.0.0,>=4.0.9
#   Downloading https://files.pythonhosted.org/packages/aa/60/81f4a1dc2d320832840288d7ec88aa3e4ee495d8f1452b4c79d8bd67136b/minio-5.0.10-py2.py3-none-any.whl (75kB)
# Collecting azure-storage-blob<3.0.0,>=2.0.1
#   Downloading https://files.pythonhosted.org/packages/3e/84/610f379b46d7d3c2d48eadeed6a12b6d46a43100fea70534f5992d0ac996/azure_storage_blob-2.1.0-py2.py3-none-any.whl (88kB)
# Collecting flatbuffers<2.0.0
#   Downloading https://files.pythonhosted.org/packages/eb/26/712e578c5f14e26ae3314c39a1bdc4eb2ec2f4ddc89b708cf8e0a0d20423/flatbuffers-1.12-py2.py3-none-any.whl
# Collecting grpcio<2.0.0
#   Downloading https://files.pythonhosted.org/packages/f3/97/f74da84d4db8cfe95f9b6aa2469be79af1873fec1adb80405105ed99a0a8/grpcio-1.28.1-cp36-cp36m-manylinux2010_x86_64.whl (2.8MB)
# Collecting pyaml<20.0.0
#   Downloading https://files.pythonhosted.org/packages/35/1e/eda9fe07f752ced7afcef590e7d74390f0d9c9c0b7ff98317afbaa0697e3/pyaml-19.12.0-py2.py3-none-any.whl
# Collecting Flask-cors<4.0.0
#   Downloading https://files.pythonhosted.org/packages/78/38/e68b11daa5d613e3a91e4bf3da76c94ac9ee0d9cd515af9c1ab80d36f709/Flask_Cors-3.0.8-py2.py3-none-any.whl
# Collecting Flask-OpenTracing<1.2.0,>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/58/6c/6417701ba5ecc8854670c6db3207bcc3e5fbc96289a7cb18d5516d99a1c6/Flask-OpenTracing-1.1.0.tar.gz
# Collecting protobuf<4.0.0
#   Downloading https://files.pythonhosted.org/packages/57/02/5432412c162989260fab61fa65e0a490c1872739eb91a659896e4d554b26/protobuf-3.11.3-cp36-cp36m-manylinux1_x86_64.whl (1.3MB)
# Collecting redis<4.0.0
#   Downloading https://files.pythonhosted.org/packages/d2/07/20cb8df2ded4b5db176a65da48b7c8d4295d868776296580b11071218a2b/redis-3.5.0-py2.py3-none-any.whl (71kB)
# Collecting requests<3.0.0
#   Downloading https://files.pythonhosted.org/packages/1a/70/1935c770cb3be6e3a8b78ced23d7e0f3b187f5cbfab4749523ed65d7c9b1/requests-2.23.0-py2.py3-none-any.whl (58kB)
# Collecting opentracing<2.3.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/94/9f/289424136addf621fb4c75624ef9a3a80e8575da3993a87950c57e93217e/opentracing-2.2.0.tar.gz (47kB)
# Collecting Flask<2.0.0
#   Downloading https://files.pythonhosted.org/packages/f2/28/2a03252dfb9ebf377f40fba6a7841b47083260bf8bd8e737b0c6952df83f/Flask-1.1.2-py2.py3-none-any.whl (94kB)
# Collecting gast>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/d6/84/759f5dd23fec8ba71952d97bcc7e2c9d7d63bdc582421f3cd4be845f0c98/gast-0.3.3-py2.py3-none-any.whl
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/site-packages (from tensorflow==1.13.1->-r requirements.txt (line 9)) (0.33.6)
# Collecting keras-preprocessing>=1.0.5
#   Downloading https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41kB)
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
# Collecting astor>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/c3/88/97eef84f48fa04fbd6750e62dcceafba6c63c81b7ac1420856c8dcc0a3f9/astor-0.8.1-py2.py3-none-any.whl
# Collecting tensorboard<1.14.0,>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/0f/39/bdd75b08a6fba41f098b6cb091b9e8c7a80e1b4d679a581a0ccd17b10373/tensorboard-1.13.1-py3-none-any.whl (3.2MB)
# Collecting six>=1.10.0
#   Downloading https://files.pythonhosted.org/packages/65/eb/1f97cb97bfc2390a276969c6fae16075da282f5058082d4cb10c6c5c1dba/six-1.14.0-py2.py3-none-any.whl
# Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/bb/48/13f49fc3fa0fdf916aa1419013bb8f2ad09674c275b4046d5ee669a46873/tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367kB)
# Collecting termcolor>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Collecting absl-py>=0.1.6
#   Downloading https://files.pythonhosted.org/packages/1a/53/9243c600e047bd4c3df9e69cfabc1e8004a82cac2e0c484580a78a94ba2a/absl-py-0.9.0.tar.gz (104kB)
# Collecting pyyaml
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
# Collecting h5py
#   Downloading https://files.pythonhosted.org/packages/60/06/cafdd44889200e5438b897388f3075b52a8ef01f28a17366d91de0fa2d05/h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl (2.9MB)
# Collecting google-cloud-core<2.0dev,>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/89/3c/8a7531839028c9690e6d14c650521f3bbaf26e53baaeb2784b8c3eb2fb97/google_cloud_core-1.3.0-py2.py3-none-any.whl
# Collecting google-auth<2.0dev,>=1.11.0
#   Downloading https://files.pythonhosted.org/packages/d2/f8/1623d69e5de22e499b68a0cb5e5d02cd6a2843e55acc19f314f48fe04299/google_auth-1.14.1-py2.py3-none-any.whl (89kB)
# Collecting google-resumable-media<0.6dev,>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/35/9e/f73325d0466ce5bdc36333f1aeb2892ead7b76e79bdb5c8b0493961fa098/google_resumable_media-0.5.0-py2.py3-none-any.whl
# Collecting table-logger>=0.3.5
#   Downloading https://files.pythonhosted.org/packages/0d/80/d4e0e9005caccae0185d4919844792a9227ebf4ed8e431c13625556b8c74/table_logger-0.3.6-py3-none-any.whl
# Collecting urllib3>=1.15.1
#   Downloading https://files.pythonhosted.org/packages/e1/e5/df302e8017440f111c11cc41a6b432838672f5a70aa29227bf58149dc72f/urllib3-1.25.9-py2.py3-none-any.whl (126kB)
# Collecting certifi>=14.05.14
#   Downloading https://files.pythonhosted.org/packages/57/2b/26e37a4b034800c960a00c4e1b3d9ca5d7014e983e6e729e33ea2f36426c/certifi-2020.4.5.1-py2.py3-none-any.whl (157kB)
# Collecting azure-batch~=4.1
#   Downloading https://files.pythonhosted.org/packages/b1/fa/1053b5dcd88e5de8e8cd70a4d7189ffad037542963ea86b518deb612c498/azure_batch-4.1.3-py2.py3-none-any.whl (314kB)
# Collecting azure-mgmt~=4.0
#   Downloading https://files.pythonhosted.org/packages/19/8e/6fa401c437579127e726487582a9861fef09022c4ab50901bb499a8e4fc1/azure_mgmt-4.0.0-py2.py3-none-any.whl
# Collecting azure-servicemanagement-legacy~=0.20.6
#   Downloading https://files.pythonhosted.org/packages/a3/2b/0813d459df7ec04bb8c6a250882ee88b672a5f8d16a237978c89436a053e/azure_servicemanagement_legacy-0.20.6-py2.py3-none-any.whl (78kB)
# Collecting azure-loganalytics~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/54/e2/1d30270441a50efce1d52eb426710fc98269eb8bdac44ee966bbd07846da/azure_loganalytics-0.1.0-py2.py3-none-any.whl
# Collecting azure-datalake-store~=0.0.18
#   Downloading https://files.pythonhosted.org/packages/27/9a/e7140775b3f8f011ef5d001c12a3519310094375671950105519e30bb12b/azure_datalake_store-0.0.48-py2.py3-none-any.whl (53kB)
# Collecting azure-graphrbac~=0.40.0
#   Downloading https://files.pythonhosted.org/packages/89/0a/29f7e2914033e2536026b8f0d7f8deb1edda68c9a93ce4757b2b1e39568b/azure_graphrbac-0.40.0-py2.py3-none-any.whl (63kB)
# Collecting azure-storage-file~=1.3
#   Downloading https://files.pythonhosted.org/packages/c9/33/6c611563412ffc409b2413ac50e3a063133ea235b86c137759774c77f3ad/azure_storage_file-1.4.0-py2.py3-none-any.whl
# Collecting azure-servicebus~=0.21.1
#   Downloading https://files.pythonhosted.org/packages/b8/de/47c0df32b57512ac9640ba239c7eeca22cb908bd8b645235729ec4f37196/azure_servicebus-0.21.1-py2.py3-none-any.whl
# Collecting azure-applicationinsights~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/3b/f7/3af9ce8a9a597998629436889cf5d69d1a0c96713e795fd372e4af785635/azure_applicationinsights-0.1.0-py2.py3-none-any.whl (104kB)
# Collecting azure-eventgrid~=1.1
#   Downloading https://files.pythonhosted.org/packages/01/e4/2a3319f04c69f0113a05884664769d462dcec55031c6d154a2c4176cfb79/azure_eventgrid-1.3.0-py2.py3-none-any.whl (167kB)
# Collecting azure-cosmosdb-table~=1.0
#   Downloading https://files.pythonhosted.org/packages/f0/e4/15a59108883cc47460b1475aeac935e2d975b5def42f2c0a8b8fd48b3304/azure_cosmosdb_table-1.0.6-py2.py3-none-any.whl (125kB)
# Collecting azure-storage-queue~=1.3
#   Downloading https://files.pythonhosted.org/packages/72/94/4db044f1c155b40c5ebc037bfd9d1c24562845692c06798fbe869fe160e6/azure_storage_queue-1.4.0-py2.py3-none-any.whl
# Collecting azure-keyvault~=1.0
#   Downloading https://files.pythonhosted.org/packages/80/37/e80f577570b32648c4b88c8c48a46501a4868ae4c8d905774fd02c2b01fc/azure_keyvault-1.1.0-py2.py3-none-any.whl (352kB)
# Collecting azure-servicefabric~=6.3.0.0
#   Downloading https://files.pythonhosted.org/packages/2c/d9/3e33ad19eb57988dff3aac06bab241736f86dc692a38c5ff6bb6fb959243/azure_servicefabric-6.3.0.0-py2.py3-none-any.whl (1.1MB)
# Collecting azure-mgmt-storage>=9.0.0
#   Downloading https://files.pythonhosted.org/packages/65/f0/8486761674c640c48219824b3ccd3cc571a792d1a0e90c8d25ed0e202d8d/azure_mgmt_storage-9.0.0-py2.py3-none-any.whl (525kB)
# Collecting boto3>=1.9.0
#   Downloading https://files.pythonhosted.org/packages/52/f6/20eee4b17af26e40a528cd4769d325bc48b0a3e614b6a92cb329417df31c/boto3-1.12.49-py2.py3-none-any.whl (128kB)
# Collecting future>=0.17.1
#   Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
# Collecting google-api-python-client>=1.7.8
#   Downloading https://files.pythonhosted.org/packages/6e/9c/e3da18a0126c4a2c0e43f824c8f8ad1c8e4afd25f3daf2b6baf7af5bd6a0/google_api_python_client-1.8.2-py3-none-any.whl (58kB)
# Collecting retrying>=1.3.3
#   Downloading https://files.pythonhosted.org/packages/44/ef/beae4b4ef80902f22e3af073397f079c96969c69b2c7d52a57ea9ae61c9d/retrying-1.3.3.tar.gz
# Collecting google-cloud-logging>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/57/75/2f5ade21f5c5bfd7cc5fb4ee9be26cdb19b9ee11cc6ea4b58656415d832f/google_cloud_logging-1.15.0-py2.py3-none-any.whl (141kB)
# Collecting httplib2>=0.12.0
#   Downloading https://files.pythonhosted.org/packages/18/9b/b95a08c373819376bf3f109bdbcff6bd4f69f2340bf708a252380319037a/httplib2-0.17.3-py3-none-any.whl (95kB)
# Collecting kubeflow-pytorchjob>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/7e/73/8a8787a8cc99a67adec5fb858e12e3f51aeb546e3470a2fe0fdbc3a81f83/kubeflow_pytorchjob-0.1.3-py3-none-any.whl (46kB)
# Collecting kfserving>=0.2.1.1
#   Downloading https://files.pythonhosted.org/packages/8c/61/8d826af3f8554f520eb8f2b4716bab29a3d924098669554672d346e71b9b/kfserving-0.3.0.1-py3-none-any.whl (83kB)
# Collecting notebook>=5.6.0
#   Downloading https://files.pythonhosted.org/packages/b1/f1/0a67f09ef53a342403ffa66646ee39273e0ac79ffa5de5dbe2f3e28b5bdf/notebook-6.0.3-py3-none-any.whl (9.7MB)
# Collecting docker>=3.4.1
#   Downloading https://files.pythonhosted.org/packages/58/74/379a9d30b1620def158c40b88c43e01c1936a287ebb97afab0699c601c57/docker-4.2.0-py2.py3-none-any.whl (143kB)
# Collecting ibm-cos-sdk>=2.6.0
#   Downloading https://files.pythonhosted.org/packages/a0/08/2b5ff7a58a237c98f9b25cd24bab8ec4f8ccb86c1ebc625d1c922f6a5816/ibm-cos-sdk-2.6.2.tar.gz (54kB)
# Collecting oauth2client>=4.0.0
#   Downloading https://files.pythonhosted.org/packages/95/a9/4f25a14d23f0786b64875b91784607c2277eff25d48f915e39ff0cff505a/oauth2client-4.1.3-py2.py3-none-any.whl (98kB)
# Collecting requests-oauthlib
#   Downloading https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0
#   Downloading https://files.pythonhosted.org/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl (200kB)
# Collecting threadloop<2,>=1
#   Downloading https://files.pythonhosted.org/packages/d3/1d/8398c1645b97dc008d3c658e04beda01ede3d90943d40c8d56863cf891bd/threadloop-1.0.2.tar.gz
# Collecting thrift
#   Downloading https://files.pythonhosted.org/packages/97/1e/3284d19d7be99305eda145b8aa46b0c33244e4a496ec66440dac19f8274d/thrift-0.13.0.tar.gz (59kB)
# Collecting configparser
#   Downloading https://files.pythonhosted.org/packages/4b/6b/01baa293090240cf0562cc5eccb69c6f5006282127f2b846fad011305c79/configparser-5.0.0-py3-none-any.whl
# Collecting azure-storage-common~=2.1
#   Downloading https://files.pythonhosted.org/packages/6b/a0/6794b318ce0118d1a4053bdf0149a60807407db9b710354f2b203c2f5975/azure_storage_common-2.1.0-py2.py3-none-any.whl (47kB)
# Collecting azure-common>=1.1.5
#   Downloading https://files.pythonhosted.org/packages/e5/4d/d000fc3c5af601d00d55750b71da5c231fcb128f42ac95b208ed1091c2c1/azure_common-1.1.25-py2.py3-none-any.whl
# Collecting chardet<4,>=3.0.2
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Collecting idna<3,>=2.5
#   Downloading https://files.pythonhosted.org/packages/89/e3/afebe61c546d18fb1709a61bee788254b40e736cff7271c7de5de2dc4128/idna-2.9-py2.py3-none-any.whl (58kB)
# Collecting Werkzeug>=0.15
#   Downloading https://files.pythonhosted.org/packages/cc/94/5f7079a0e00bd6863ef8f1da638721e9da21e5bacee597595b318f71d62e/Werkzeug-1.0.1-py2.py3-none-any.whl (298kB)
# Collecting itsdangerous>=0.24
#   Downloading https://files.pythonhosted.org/packages/76/ae/44b03b253d6fade317f32c24d100b3b35c2239807046a4c953c7b89fa49e/itsdangerous-1.1.0-py2.py3-none-any.whl
# Collecting click>=5.1
#   Downloading https://files.pythonhosted.org/packages/d2/3d/fa76db83bf75c4f8d338c2fd15c8d33fdd7ad23a9b5e57eb6c5de26b430e/click-7.1.2-py2.py3-none-any.whl (82kB)
# Collecting Jinja2>=2.10.1
#   Downloading https://files.pythonhosted.org/packages/30/9e/f663a2aa66a09d838042ae1a2c5659828bb9b41ea3a6efa20a20fd92b121/Jinja2-2.11.2-py2.py3-none-any.whl (125kB)
# Collecting markdown>=2.6.8
#   Downloading https://files.pythonhosted.org/packages/ab/c4/ba46d44855e6eb1770a12edace5a165a0c6de13349f592b9036257f3c3d3/Markdown-3.2.1-py2.py3-none-any.whl (88kB)
# Collecting mock>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/cd/74/d72daf8dff5b6566db857cfd088907bb0355f5dd2914c4b3ef065c790735/mock-4.0.2-py3-none-any.whl
# Collecting google-api-core<2.0.0dev,>=1.16.0
#   Downloading https://files.pythonhosted.org/packages/4c/b9/c0dd70bcdf06a43d1e21f387448e7997e0ce91f10d0fbee359af4cde1571/google_api_core-1.17.0-py2.py3-none-any.whl (70kB)
# Collecting rsa<4.1,>=3.1.4
#   Downloading https://files.pythonhosted.org/packages/02/e5/38518af393f7c214357079ce67a317307936896e961e35450b70fad2a9cf/rsa-4.0-py2.py3-none-any.whl
# Collecting cachetools<5.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/b3/59/524ffb454d05001e2be74c14745b485681c6ed5f2e625f71d135704c0909/cachetools-4.1.0-py3-none-any.whl
# Collecting pyasn1-modules>=0.2.1
#   Downloading https://files.pythonhosted.org/packages/95/de/214830a981892a3e286c3794f41ae67a4495df1108c3da8a9f62159b9a9d/pyasn1_modules-0.2.8-py2.py3-none-any.whl (155kB)
# Collecting azure-nspkg>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/c4/0c/c562be95a9a2ed52454f598571cf300b1114d0db2aa27f5b8ed3bb9cd0c0/azure_nspkg-3.0.2-py3-none-any.whl
# Collecting msrestazure<2.0.0,>=0.4.20
#   Downloading https://files.pythonhosted.org/packages/01/70/4abd575d876428e3892ca6b7acafb59b53cb9923fa6aec2cbbf173495ce1/msrestazure-0.6.3-py2.py3-none-any.whl (40kB)
# Collecting azure-mgmt-monitor~=0.5.2
#   Downloading https://files.pythonhosted.org/packages/6a/3b/a8b95ee25f1c209ad82ad06de39f4efbfb9dc8a8dc5da5a7a48d7897bf3e/azure_mgmt_monitor-0.5.2-py2.py3-none-any.whl (247kB)
# Collecting azure-mgmt-hanaonazure~=0.1.1
#   Downloading https://files.pythonhosted.org/packages/f3/1b/50d300ae02158ab092f923132050b56c148f1b784c7b594d3275d4449769/azure_mgmt_hanaonazure-0.1.1-py2.py3-none-any.whl
# Collecting azure-mgmt-media~=1.0.0rc2
#   Downloading https://files.pythonhosted.org/packages/65/2e/6d9649bd5645ac32a179adfea5707f640fc51a57e493c27f0ab575789e85/azure_mgmt_media-1.0.0-py2.py3-none-any.whl (335kB)
# Collecting azure-mgmt-recoveryservices~=0.3.0
#   Downloading https://files.pythonhosted.org/packages/fd/7f/80327a27e03473101afb136e872279ad1386adf1bac14a58a9f839cd8352/azure_mgmt_recoveryservices-0.3.0-py2.py3-none-any.whl (70kB)
# Collecting azure-mgmt-datamigration~=1.0
#   Downloading https://files.pythonhosted.org/packages/8b/4f/7b149487e77d94e701288e1d0b066a7d522bdfe8595e992b5d39dfb00f80/azure_mgmt_datamigration-1.0.0-py2.py3-none-any.whl (185kB)
# Collecting azure-mgmt-rdbms~=1.2
#   Downloading https://files.pythonhosted.org/packages/d2/94/c850c8257d19b08eb6b03154d6fe21938801562b4082d27985f54ebe9de4/azure_mgmt_rdbms-1.9.0-py2.py3-none-any.whl (259kB)
# Collecting azure-mgmt-consumption~=2.0
#   Downloading https://files.pythonhosted.org/packages/11/f4/2db9557494dfb17ff3edeae5726981143a7baace17df3712b189e343bd8c/azure_mgmt_consumption-2.0.0-py2.py3-none-any.whl (46kB)
# Collecting azure-mgmt-loganalytics~=0.2.0
#   Downloading https://files.pythonhosted.org/packages/70/40/c9b77bf82916e963aa701fb396673f7ddc4cdab95524b6d2edf927b05630/azure_mgmt_loganalytics-0.2.0-py2.py3-none-any.whl (89kB)
# Collecting azure-mgmt-servicefabric~=0.2.0
#   Downloading https://files.pythonhosted.org/packages/6e/06/fafe8b5d881cfa68927e61557c8419dcfacb93e07f4ab17cc60959707a53/azure_mgmt_servicefabric-0.2.0-py2.py3-none-any.whl (142kB)
# Collecting azure-mgmt-advisor~=1.0
#   Downloading https://files.pythonhosted.org/packages/cb/f3/a86ba3e0784d12c8fe5cbf1f24e1b9255575a2f0892e08c46cddd0795dfd/azure_mgmt_advisor-1.0.1-py2.py3-none-any.whl
# Collecting azure-mgmt-maps~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/e4/04/c64326729e842f3eab1fd527f7582e269e4b0e5b9324a4562edaf0371953/azure_mgmt_maps-0.1.0-py2.py3-none-any.whl
# Collecting azure-mgmt-managementgroups~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/f2/50/591adac2a6cd8d77cccd38bdf5d177ad6a2e95b9217daa9a60b5d86de5cd/azure_mgmt_managementgroups-0.1.0-py2.py3-none-any.whl (59kB)
# Collecting azure-mgmt-iotcentral~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/58/4e/e2e5f2d545a46ada3705c85c45c12882a443d40f60e1a908c78058e15cf2/azure_mgmt_iotcentral-0.1.0-py2.py3-none-any.whl
# Collecting azure-mgmt-containerinstance~=1.0
#   Downloading https://files.pythonhosted.org/packages/fd/d1/d770050f20ad81b80f7eb41f89e1a5d841cf74bf41c7e1ff137c46f28a1e/azure_mgmt_containerinstance-1.5.0-py2.py3-none-any.whl (96kB)
# Collecting azure-mgmt-containerservice~=4.2
#   Downloading https://files.pythonhosted.org/packages/5b/2f/0eba2dbd5d3f66c076a66b0020ccfe9c7e78534ac132afaa104c138680c1/azure_mgmt_containerservice-4.4.0-py2.py3-none-any.whl (206kB)
# Collecting azure-mgmt-containerregistry~=2.1
#   Downloading https://files.pythonhosted.org/packages/97/70/8c2d0509db466678eba16fa2b0a539499f3b351b1f2993126ad843d5be13/azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718kB)
# Collecting azure-mgmt-logic~=3.0
#   Downloading https://files.pythonhosted.org/packages/88/98/693c515e97043520f5cebf1ecae7bf198df100f5f9870b53d4be3bcaa5ce/azure_mgmt_logic-3.0.0-py2.py3-none-any.whl (303kB)
# Collecting azure-mgmt-web~=0.35.0
#   Downloading https://files.pythonhosted.org/packages/21/04/3f2622720664c972d927fd9e58c0066e998739b7891649207765be674126/azure_mgmt_web-0.35.0-py2.py3-none-any.whl (358kB)
# Collecting azure-mgmt-scheduler~=2.0
#   Downloading https://files.pythonhosted.org/packages/e8/55/f3490698ff622244438e667e0321808e84389e69c5fb77a1d6db869d9bb7/azure_mgmt_scheduler-2.0.0-py2.py3-none-any.whl (67kB)
# Collecting azure-mgmt-servicebus~=0.5.1
#   Downloading https://files.pythonhosted.org/packages/28/ad/9e90f8bab40a9682410e57ed08a799be113c5e470bec247b099038c6389e/azure_mgmt_servicebus-0.5.3-py2.py3-none-any.whl (112kB)
# Collecting azure-mgmt-dns~=2.0
#   Downloading https://files.pythonhosted.org/packages/c7/d7/0f986a64b06db93cf29b76f9a188f5778eb959624a00ed6aedc335ee58d2/azure_mgmt_dns-2.1.0-py2.py3-none-any.whl (134kB)
# Collecting azure-mgmt-authorization~=0.50.0
#   Downloading https://files.pythonhosted.org/packages/6f/17/55b974603c16be89c7a7c16bac57b7bce48527bf1bebc3f116f7215176e6/azure_mgmt_authorization-0.50.0-py2.py3-none-any.whl (81kB)
# Collecting azure-mgmt-machinelearningcompute~=0.4.1
#   Downloading https://files.pythonhosted.org/packages/b4/9c/f8eb81b307df4465809b182f2fe44c288eeb41c0ab54f91b61ac554998a9/azure_mgmt_machinelearningcompute-0.4.1-py2.py3-none-any.whl
# Collecting azure-mgmt-devtestlabs~=2.2
#   Downloading https://files.pythonhosted.org/packages/2f/93/a64abaede2fc6a52476af8ceab9cedb368c49e948d9385cbe7cd4ce5ffff/azure_mgmt_devtestlabs-2.2.0-py2.py3-none-any.whl (194kB)
# Collecting azure-mgmt-batchai~=2.0
#   Downloading https://files.pythonhosted.org/packages/d9/a5/ab796c2a490155c14f9ac4240724ca5c56723315d4dc753030712e6f2e80/azure_mgmt_batchai-2.0.0-py2.py3-none-any.whl (174kB)
# Collecting azure-mgmt-iothub~=0.5.0
#   Downloading https://files.pythonhosted.org/packages/19/d6/b422df467b3d7f4e2975b590fbf6e12aaae0a497c7d080b4955a6a6d794a/azure_mgmt_iothub-0.5.0-py2.py3-none-any.whl (102kB)
# Collecting azure-mgmt-msi~=0.2.0
#   Downloading https://files.pythonhosted.org/packages/ae/95/b451721e38ca0feddce03ee3ce86158e208d0150253bd371207a8df4e9c5/azure_mgmt_msi-0.2.0-py2.py3-none-any.whl
# Collecting azure-mgmt-datalake-analytics~=0.6.0
#   Downloading https://files.pythonhosted.org/packages/73/e7/5d909ef5812fc31f2871f3510ef43af93157ba51be03b6f798afba7a29d8/azure_mgmt_datalake_analytics-0.6.0-py2.py3-none-any.whl (288kB)
# Collecting azure-mgmt-trafficmanager~=0.50.0
#   Downloading https://files.pythonhosted.org/packages/ed/4f/c322d72dc92dde543471bc23f9ac0eb6b9d0dc2441bb5ce938250040e307/azure_mgmt_trafficmanager-0.50.0-py2.py3-none-any.whl (52kB)
# Collecting azure-mgmt-resource~=2.0
#   Downloading https://files.pythonhosted.org/packages/1b/2d/9c3f2c9bf6e19f3efe4ddcaa946ea515d5229f4c0b387e224267e77fb73b/azure_mgmt_resource-2.2.0-py2.py3-none-any.whl (780kB)
# Collecting azure-mgmt-network~=2.0
#   Downloading https://files.pythonhosted.org/packages/61/95/d63833e95406626256893a2f3ef4e5029a168330e3a27817a9f5597c0e6f/azure_mgmt_network-2.7.0-py2.py3-none-any.whl (11.4MB)
# Collecting azure-mgmt-billing~=0.2.0
#   Downloading https://files.pythonhosted.org/packages/0f/24/5106287ea0f6562d965afb055e3c6c0da058f7844a70464e67bab56c6c4b/azure_mgmt_billing-0.2.0-py2.py3-none-any.whl
# Collecting azure-mgmt-batch~=5.0
#   Downloading https://files.pythonhosted.org/packages/97/81/a9eb3fd2ab070159105b4cfe9640c24410ac8195286729d62bfdf871de94/azure_mgmt_batch-5.0.1-py2.py3-none-any.whl (87kB)
# Collecting azure-mgmt-reservations~=0.2.1
#   Downloading https://files.pythonhosted.org/packages/a9/2b/e0edb8dbe85e447005cde508b869e564f58270f631219f036d8ab71184f9/azure_mgmt_reservations-0.2.1-py2.py3-none-any.whl (50kB)
# Collecting azure-mgmt-powerbiembedded~=2.0
#   Downloading https://files.pythonhosted.org/packages/64/2b/5a69d118626a83055ce577fb6ba35c114e72f0273d0c4d943b909ee8d51e/azure_mgmt_powerbiembedded-2.0.0-py2.py3-none-any.whl
# Collecting azure-mgmt-commerce~=1.0
#   Downloading https://files.pythonhosted.org/packages/7e/13/f421e77dd1fe3c9657a890f9c085f433fe422f54003ee03e631a8be5c4e7/azure_mgmt_commerce-1.0.1-py2.py3-none-any.whl
# Collecting azure-mgmt-datalake-store~=0.5.0
#   Downloading https://files.pythonhosted.org/packages/ff/ac/5685cd06dc8b245bb6b894815764a14bd62245ba4579b45148682f510fdd/azure_mgmt_datalake_store-0.5.0-py2.py3-none-any.whl (88kB)
# Collecting azure-mgmt-devspaces~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/f4/d3/ff9c39578f24fb4bd158a882788c7795b177cf3f23ce7cf1d8b52066a64e/azure_mgmt_devspaces-0.1.0-py2.py3-none-any.whl
# Collecting azure-mgmt-applicationinsights~=0.1.1
#   Downloading https://files.pythonhosted.org/packages/30/61/1d95a5ef3a9119a0d375d8670129375515de20e20409612e9671c99bd19f/azure_mgmt_applicationinsights-0.1.1-py2.py3-none-any.whl (42kB)
# Collecting azure-mgmt-cdn~=3.0
#   Downloading https://files.pythonhosted.org/packages/97/bf/c41e8985b4ffaaad2baaded1fb7b113433ae2d30d65c1a8c226e72284b72/azure_mgmt_cdn-3.1.0-py2.py3-none-any.whl (119kB)
# Collecting azure-mgmt-cosmosdb~=0.4.1
#   Downloading https://files.pythonhosted.org/packages/17/ed/d97a04c8c26e2432f2cf000b711daeb053e1cfbdb046bd5d070c941b4fcb/azure_mgmt_cosmosdb-0.4.1-py2.py3-none-any.whl (100kB)
# Collecting azure-mgmt-datafactory~=0.6.0
#   Downloading https://files.pythonhosted.org/packages/cf/01/32a6ad5ad348d965f7c106d819a1f6dc613f6aa98a720ffc529ef468016b/azure_mgmt_datafactory-0.6.0-py2.py3-none-any.whl (418kB)
# Collecting azure-mgmt-keyvault~=1.0
#   Downloading https://files.pythonhosted.org/packages/49/de/0d69aedae7c5f6428314640b65947203ab80409c12b5d4e66fb5b7a4182e/azure_mgmt_keyvault-1.1.0-py2.py3-none-any.whl (111kB)
# Collecting azure-mgmt-managementpartner~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/9a/91/2bccd2bdca4158a7b6169538b25e22e0b4f8ff835754888aab45ffbd0448/azure_mgmt_managementpartner-0.1.1-py2.py3-none-any.whl
# Collecting azure-mgmt-iothubprovisioningservices~=0.2.0
#   Downloading https://files.pythonhosted.org/packages/84/ce/3500c731a5c5b31028e662aa41bc45f75301834a0c03adeacfe7ef7bd86e/azure_mgmt_iothubprovisioningservices-0.2.0-py2.py3-none-any.whl (60kB)
# Collecting azure-mgmt-eventgrid~=1.0
#   Downloading https://files.pythonhosted.org/packages/54/5b/e91e616021ae9be0019c9c19cffb92b97d787246ca51cfcc0b0a0c6da77a/azure_mgmt_eventgrid-1.0.0-py2.py3-none-any.whl (51kB)
# Collecting azure-mgmt-cognitiveservices~=3.0
#   Downloading https://files.pythonhosted.org/packages/8d/c8/222ea2f533c6b8f8656f3091101b4c3aa32c162d2a609d07d1ae00172515/azure_mgmt_cognitiveservices-3.0.0-py2.py3-none-any.whl (58kB)
# Collecting azure-mgmt-eventhub~=2.1
#   Downloading https://files.pythonhosted.org/packages/5a/cb/3822bcfa815f894c86a27845ae4160c0169722598399234cd6f77bb82347/azure_mgmt_eventhub-2.6.0-py2.py3-none-any.whl (189kB)
# Collecting azure-mgmt-redis~=5.0
#   Downloading https://files.pythonhosted.org/packages/90/a7/42342a984b2916972c5c5e24df94e3cd5e4377a8dc465a83415706d9be6f/azure_mgmt_redis-5.0.0-py2.py3-none-any.whl (43kB)
# Collecting azure-mgmt-policyinsights~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/19/84/7021951ae69572a19af0ff9cca1d2abf3542d35af38796656ded1be08358/azure_mgmt_policyinsights-0.1.0-py2.py3-none-any.whl (44kB)
# Collecting azure-mgmt-signalr~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/10/32/379137548a4c6e4dfd15da6b1c476f2b1af52e8d7fe243fdac9ea2064427/azure_mgmt_signalr-0.1.1-py2.py3-none-any.whl (49kB)
# Collecting azure-mgmt-subscription~=0.2.0
#   Downloading https://files.pythonhosted.org/packages/27/72/f63f72d9c27659f96aae287f7ba67c9ba2877213c2c10d8b797e0dee5059/azure_mgmt_subscription-0.2.0-py2.py3-none-any.whl (40kB)
# Collecting azure-mgmt-search~=2.0
#   Downloading https://files.pythonhosted.org/packages/c9/18/fa4e0d541332c0ba6ef16beaa9b55f831436949e7d0981d5677dff2ddfb5/azure_mgmt_search-2.1.0-py2.py3-none-any.whl (41kB)
# Collecting azure-mgmt-sql~=0.9.1
#   Downloading https://files.pythonhosted.org/packages/c5/bb/219c76af961e9e6d1f5055d70c3cc06889b91375727a04367149c3aad640/azure_mgmt_sql-0.9.1-py2.py3-none-any.whl (485kB)
# Collecting azure-mgmt-marketplaceordering~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/a8/cb/13502fdbaf520d08fb280eb31ecfe5d926b9cf92259c22280bbde96b307d/azure_mgmt_marketplaceordering-0.1.0-py2.py3-none-any.whl
# Collecting azure-mgmt-recoveryservicesbackup~=0.3.0
#   Downloading https://files.pythonhosted.org/packages/c5/af/13b10d76bc0ff9188c9e5cd9f2726a5745029b76125938491f9abac5399d/azure_mgmt_recoveryservicesbackup-0.3.0-py2.py3-none-any.whl (568kB)
# Collecting azure-mgmt-relay~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/00/f7/f5c72bd19829cfaf9f070ec294c901ad7f98835ba9560fdad652afb1071f/azure_mgmt_relay-0.1.0-py2.py3-none-any.whl
# Collecting azure-mgmt-compute~=4.0
#   Downloading https://files.pythonhosted.org/packages/0e/4d/7ac30585c567a8b9fe8294e0e956c6ef48665522ddf8f8c44bf38b700798/azure_mgmt_compute-4.6.2-py2.py3-none-any.whl (3.0MB)
# Collecting azure-mgmt-notificationhubs~=2.0
#   Downloading https://files.pythonhosted.org/packages/55/c0/62a0495583dfc44830f711be52cb4a4e116c2f72c89a19b90d654bdafc4a/azure_mgmt_notificationhubs-2.1.0-py2.py3-none-any.whl (76kB)
# Collecting msrest<2.0.0,>=0.4.29
#   Downloading https://files.pythonhosted.org/packages/56/f2/e2f9e4dc72884fff27e68ceaf027b9a3b80ba16f5757fc2916cb5d9117bd/msrest-0.6.13-py2.py3-none-any.whl (83kB)
# Collecting adal>=0.4.2
#   Downloading https://files.pythonhosted.org/packages/4f/b5/3ea9ae3d1096b9ff31e8f1846c47d49f3129a12464ac0a73b602de458298/adal-1.2.2-py2.py3-none-any.whl (53kB)
# Collecting cffi
#   Downloading https://files.pythonhosted.org/packages/f1/c7/72abda280893609e1ddfff90f8064568bd8bcb2c1770a9d5bb5edb2d1fea/cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399kB)
# Collecting cryptography
#   Downloading https://files.pythonhosted.org/packages/3c/04/686efee2dcdd25aecf357992e7d9362f443eb182ecd623f882bc9f7a6bba/cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7MB)
# Collecting azure-cosmosdb-nspkg>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/58/0d/1329b47e5386b0acf4e42ada2284851eff60ef3337a87e5b2dfedabbfcb1/azure_cosmosdb_nspkg-2.0.2-py2.py3-none-any.whl
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/a3/43/1e939e1fcd87b827fe192d0c9fc25b48c5b3368902bfb913de7754b0dc03/jmespath-0.9.5-py2.py3-none-any.whl
# Collecting botocore<1.16.0,>=1.15.49
#   Downloading https://files.pythonhosted.org/packages/0f/2c/80605ef2f2800815dd2b0be0000295481b8e965b94541a3ed245c683c6f2/botocore-1.15.49-py2.py3-none-any.whl (6.2MB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/69/79/e6afb3d8b0b4e96cefbdc690f741d7dd24547ff1f94240c997a26fa908d3/s3transfer-0.3.3-py2.py3-none-any.whl (69kB)
# Collecting google-auth-httplib2>=0.0.3
#   Downloading https://files.pythonhosted.org/packages/33/49/c814d6d438b823441552198f096fcd0377fd6c88714dbed34f1d3c8c4389/google_auth_httplib2-0.0.3-py2.py3-none-any.whl
# Collecting uritemplate<4dev,>=3.0.0
#   Downloading https://files.pythonhosted.org/packages/bf/0c/60d82c077998feb631608dca3cc1fe19ac074e772bf0c24cf409b977b815/uritemplate-3.0.1-py2.py3-none-any.whl
# Collecting argparse>=1.4.0
#   Downloading https://files.pythonhosted.org/packages/f2/94/3af39d34be01a24a6e65433d19e107099374224905f1e0cc6bbe1fd22a2f/argparse-1.4.0-py2.py3-none-any.whl
# Collecting ipython-genutils
#   Downloading https://files.pythonhosted.org/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl
# Collecting jupyter-core>=4.6.1
#   Downloading https://files.pythonhosted.org/packages/63/0d/df2d17cdf389cea83e2efa9a4d32f7d527ba78667e0153a8e676e957b2f7/jupyter_core-4.6.3-py2.py3-none-any.whl (83kB)
# Collecting terminado>=0.8.1
#   Downloading https://files.pythonhosted.org/packages/ff/96/1d9a2c23990aea8f8e0b5c3b6627d03196a73771a17a2d9860bbe9823ab6/terminado-0.8.3-py2.py3-none-any.whl
# Collecting pyzmq>=17
#   Downloading https://files.pythonhosted.org/packages/41/fa/e6e10410f01b03d10ab0705717d1246f63cdbbc0676140c78f0f757db332/pyzmq-19.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
# Collecting jupyter-client>=5.3.4
#   Downloading https://files.pythonhosted.org/packages/34/0b/2ebddf775f558158ca8df23b35445fb15d4b1558a9e4a03bc7e75b13476e/jupyter_client-6.1.3-py3-none-any.whl (106kB)
# Collecting ipykernel
#   Downloading https://files.pythonhosted.org/packages/ed/5d/cf47741fa80826f8edf435d9bcf0e84eef2d6d02953ff85e0563b3ab3f0b/ipykernel-5.2.1-py3-none-any.whl (118kB)
# Collecting nbconvert
#   Downloading https://files.pythonhosted.org/packages/79/6c/05a569e9f703d18aacb89b7ad6075b404e8a4afde2c26b73ca77bb644b14/nbconvert-5.6.1-py2.py3-none-any.whl (455kB)
# Collecting traitlets>=4.2.1
#   Downloading https://files.pythonhosted.org/packages/ca/ab/872a23e29cec3cf2594af7e857f18b687ad21039c1f9b922fac5b9b142d5/traitlets-4.3.3-py2.py3-none-any.whl (75kB)
# Collecting Send2Trash
#   Downloading https://files.pythonhosted.org/packages/49/46/c3dc27481d1cc57b9385aff41c474ceb7714f7935b1247194adae45db714/Send2Trash-1.5.0-py3-none-any.whl
# Collecting nbformat
#   Downloading https://files.pythonhosted.org/packages/d5/3c/251cfe5e3c9545ece107d342909ee3822d8cd9f3f11a591df37baeff2089/nbformat-5.0.6-py3-none-any.whl (170kB)
# Collecting ibm-cos-sdk-core==2.6.2
#   Downloading https://files.pythonhosted.org/packages/c1/f0/ebb57ccf2d3dc567988cea6a6ba778ebbf96bc4f40039866757dd97cb80a/ibm-cos-sdk-core-2.6.2.tar.gz (787kB)
# Collecting ibm-cos-sdk-s3transfer==2.6.2
#   Downloading https://files.pythonhosted.org/packages/c9/5e/11d12801a51cb74272d4f6072b4da5570d6739137e11f6573b6c043b3160/ibm-cos-sdk-s3transfer-2.6.2.tar.gz (131kB)
# Collecting pyasn1>=0.1.7
#   Downloading https://files.pythonhosted.org/packages/62/1e/a94a8d635fa3ce4cfc7f506003548d0a2447ae76fd5ca53932970fe3053f/pyasn1-0.4.8-py2.py3-none-any.whl (77kB)
# Collecting oauthlib>=3.0.0
#   Downloading https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl (147kB)
# Collecting MarkupSafe>=0.23
#   Downloading https://files.pythonhosted.org/packages/b2/5f/23e0023be6bb885d00ffbefad2942bc51a620328ee910f64abe5a8d18dd1/MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading https://files.pythonhosted.org/packages/05/46/168fd780f594a4d61122f7f3dc0561686084319ad73b4febbf02ae8b32cf/googleapis-common-protos-1.51.0.tar.gz
# Collecting azure-mgmt-nspkg>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/b3/c2/af4b47845f27dc7d206ed4908b9e580f8bc94a4b2f3956a0d87c40719d90/azure_mgmt_nspkg-3.0.2-py3-none-any.whl
# Collecting azure-mgmt-datalake-nspkg>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/48/3d/c65a520d93448923a96784582a0deafaae096cb37b444ae5d63b57f0562d/azure_mgmt_datalake_nspkg-3.0.1-py3-none-any.whl
# Collecting isodate>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
# Collecting PyJWT>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Collecting pycparser
#   Downloading https://files.pythonhosted.org/packages/ae/e7/d9c3a176ca4b02024debf82342dab36efadfc5776f9c8db077e8f6e71821/pycparser-2.20-py2.py3-none-any.whl (112kB)
# Collecting docutils<0.16,>=0.10
#   Downloading https://files.pythonhosted.org/packages/22/cd/a6aa959dca619918ccb55023b4cb151949c64d4d5d55b3f4ffd7eee0c6e8/docutils-0.15.2-py3-none-any.whl (547kB)
# Collecting ptyprocess; os_name != "nt"
#   Downloading https://files.pythonhosted.org/packages/d1/29/605c2cc68a9992d18dada28206eeada56ea4bd07a239669da41674648b6f/ptyprocess-0.6.0-py2.py3-none-any.whl
# Collecting ipython>=5.0.0
#   Downloading https://files.pythonhosted.org/packages/61/6f/69f1eec859ce48a86660529b166b6ea466f0f4ab98e4fc0807b835aa22c6/ipython-7.13.0-py3-none-any.whl (780kB)
# Collecting pygments
#   Downloading https://files.pythonhosted.org/packages/2d/68/106af3ae51daf807e9cdcba6a90e518954eb8b70341cee52995540a53ead/Pygments-2.6.1-py3-none-any.whl (914kB)
# Collecting bleach
#   Downloading https://files.pythonhosted.org/packages/9a/1e/7d6cb3b27cd2c490558349ca5d5cc05b390b017da1c704cac807ac8bd9fb/bleach-3.1.5-py2.py3-none-any.whl (151kB)
# Collecting defusedxml
#   Downloading https://files.pythonhosted.org/packages/06/74/9b387472866358ebc08732de3da6dc48e44b0aacd2ddaa5cb85ab7e986a2/defusedxml-0.6.0-py2.py3-none-any.whl
# Collecting mistune<2,>=0.8.1
#   Downloading https://files.pythonhosted.org/packages/09/ec/4b43dae793655b7d8a25f76119624350b4d65eb663459eb9603d7f1f0345/mistune-0.8.4-py2.py3-none-any.whl
# Collecting pandocfilters>=1.4.1
#   Downloading https://files.pythonhosted.org/packages/4c/ea/236e2584af67bb6df960832731a6e5325fd4441de001767da328c33368ce/pandocfilters-1.4.2.tar.gz
# Collecting testpath
#   Downloading https://files.pythonhosted.org/packages/1b/9e/1a170feaa54f22aeb5a5d16c9015e82234275a3c8ab630b552493f9cb8a9/testpath-0.4.4-py2.py3-none-any.whl (163kB)
# Collecting entrypoints>=0.2.2
#   Downloading https://files.pythonhosted.org/packages/ac/c6/44694103f8c221443ee6b0041f69e2740d89a25641e62fb4f2ee568f2f9c/entrypoints-0.3-py2.py3-none-any.whl
# Collecting decorator
#   Downloading https://files.pythonhosted.org/packages/ed/1b/72a1821152d07cf1d8b6fce298aeb06a7eb90f4d6d41acec9861e7cc6df0/decorator-4.4.2-py2.py3-none-any.whl
# Collecting jsonschema!=2.5.0,>=2.4
#   Downloading https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl (56kB)
# Collecting pickleshare
#   Downloading https://files.pythonhosted.org/packages/9a/41/220f49aaea88bc6fa6cba8d05ecf24676326156c23b991e80b3f2fc24c77/pickleshare-0.7.5-py2.py3-none-any.whl
# Collecting pexpect; sys_platform != "win32"
#   Downloading https://files.pythonhosted.org/packages/39/7b/88dbb785881c28a102619d46423cb853b46dbccc70d3ac362d99773a78ce/pexpect-4.8.0-py2.py3-none-any.whl (59kB)
# Collecting jedi>=0.10
#   Downloading https://files.pythonhosted.org/packages/f3/3f/67f027e18c60a800875df1a0894a2436ce9053637fa39725766e937c0a71/jedi-0.17.0-py2.py3-none-any.whl (1.1MB)
# Collecting backcall
#   Downloading https://files.pythonhosted.org/packages/84/71/c8ca4f5bb1e08401b916c68003acf0a0655df935d74d93bf3f3364b310e0/backcall-0.1.0.tar.gz
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/e4/a7/81b39aa50e9284fe2cb21cc7fb7de7817b224172d42793fd57451d38842b/prompt_toolkit-3.0.5-py3-none-any.whl (351kB)
# Collecting webencodings
#   Downloading https://files.pythonhosted.org/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl
# Collecting packaging
#   Downloading https://files.pythonhosted.org/packages/62/0a/34641d2bf5c917c96db0ded85ae4da25b6cd922d6b794648d4e7e07c88e5/packaging-20.3-py2.py3-none-any.whl
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading https://files.pythonhosted.org/packages/ad/e4/891bfcaf868ccabc619942f27940c77a8a4b45fd8367098955bb7e152fb1/importlib_metadata-1.6.0-py2.py3-none-any.whl
# Collecting attrs>=17.4.0
#   Downloading https://files.pythonhosted.org/packages/a2/db/4313ab3be961f7a763066401fb77f7748373b6094076ae2bda2806988af6/attrs-19.3.0-py2.py3-none-any.whl
# Collecting pyrsistent>=0.14.0
#   Downloading https://files.pythonhosted.org/packages/9f/0d/cbca4d0bbc5671822a59f270e4ce3f2195f8a899c97d0d5abb81b191efb5/pyrsistent-0.16.0.tar.gz (108kB)
# Collecting parso>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/b5/61/998cce9e7476de000d031874df26a18f67cb73448164fc44a98f0c55920b/parso-0.7.0-py2.py3-none-any.whl (100kB)
# Collecting wcwidth
#   Downloading https://files.pythonhosted.org/packages/f6/d5/1ecdac957e3ea12c1b319fcdee8b6917ffaff8b4644d673c4d72d2f20b49/wcwidth-0.1.9-py2.py3-none-any.whl
# Collecting pyparsing>=2.0.2
#   Downloading https://files.pythonhosted.org/packages/8a/bb/488841f56197b13700afd5658fc279a2025a39e22449b7cf29864669b15d/pyparsing-2.4.7-py2.py3-none-any.whl (67kB)
# Collecting zipp>=0.5
#   Downloading https://files.pythonhosted.org/packages/b2/34/bfcb43cc0ba81f527bc4f40ef41ba2ff4080e047acb0586b56b3d017ace4/zipp-3.1.0-py3-none-any.whl
# Building wheels for collected packages: tornado, prometheus-client, jaeger-client, Flask-OpenTracing, opentracing, termcolor, absl-py, pyyaml, future, retrying, ibm-cos-sdk, threadloop, thrift, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer, googleapis-common-protos, pandocfilters, backcall, pyrsistent
#   Building wheel for tornado (setup.py): started
#   Building wheel for tornado (setup.py): finished with status 'done'
#   Created wheel for tornado: filename=tornado-6.0.4-cp36-cp36m-linux_x86_64.whl size=427966 sha256=855b97a7a6e827ecc489ae1a4471d6e994cc1a688a48ee0bb88f7ba2a5a6a2e7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nrqteu2j/wheels/93/84/2f/409c7b2bb3afc3aa727f7ee8787975e0793f74d1165f4d0104
#   Building wheel for prometheus-client (setup.py): started
#   Building wheel for prometheus-client (setup.py): finished with status 'done'
#   Created wheel for prometheus-client: filename=prometheus_client-0.7.1-cp36-none-any.whl size=41402 sha256=af4c3d6d6fe4f45ec87ff8109320ff64e2a981e61ed6b0f6824cbac4bb92591f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nrqteu2j/wheels/1c/54/34/fd47cd9b308826cc4292b54449c1899a30251ef3b506bc91ea
#   Building wheel for jaeger-client (setup.py): started
#   Building wheel for jaeger-client (setup.py): finished with status 'done'
#   Created wheel for jaeger-client: filename=jaeger_client-4.1.0-cp36-none-any.whl size=64309 sha256=04f8d6ddb999a42f659f293366d5b583de4b7842a5d909519bc7bdc35aba8b79
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nrqteu2j/wheels/f2/84/7f/e89da3ee8ce35598d6382b6389fa2ada5d66acca2422537994
#   Building wheel for Flask-OpenTracing (setup.py): started
#   Building wheel for Flask-OpenTracing (setup.py): finished with status 'done'
# ...
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nrqteu2j/wheels/d7/a9/33/acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c
#   Building wheel for ibm-cos-sdk (setup.py): started
#   Building wheel for ibm-cos-sdk (setup.py): finished with status 'done'
#   Created wheel for ibm-cos-sdk: filename=ibm_cos_sdk-2.6.2-py2.py3-none-any.whl size=72497 sha256=12f4b6bf11240ebabdec28a3dfb33048f2a067226c46ee76d796152d266c633e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nrqteu2j/wheels/8c/4b/43/e3606c88bd7f0169a587d82ad79f5f826f91983106eec3e22b
#   Building wheel for threadloop (setup.py): started
#   Building wheel for threadloop (setup.py): finished with status 'done'
#   Created wheel for threadloop: filename=threadloop-1.0.2-cp36-none-any.whl size=3425 sha256=917cfcf16315d49d04be92d1e4ca827a4d783286c74c126a99538e862c12a66b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nrqteu2j/wheels/d7/7a/30/d212623a4cd34f6cce400f8122b1b7af740d3440c68023d51f
#   Building wheel for thrift (setup.py): started
#   Building wheel for thrift (setup.py): finished with status 'done'
#   Created wheel for thrift: filename=thrift-0.13.0-cp36-cp36m-linux_x86_64.whl size=483934 sha256=72efd8b300c8c568dee97bab7e4a321236b16bc615ada38bf22ffbcd0789a271
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nrqteu2j/wheels/02/a2/46/689ccfcf40155c23edc7cdbd9de488611c8fdf49ff34b1706e
#   Building wheel for ibm-cos-sdk-core (setup.py): started
#   Building wheel for ibm-cos-sdk-core (setup.py): finished with status 'done'
#   Created wheel for ibm-cos-sdk-core: filename=ibm_cos_sdk_core-2.6.2-py2.py3-none-any.whl size=462042 sha256=e98cb810c67f5d4f3d7ac81de855da04d5ddf3f8ebe65b30a9e28357ac013a3e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nrqteu2j/wheels/16/82/37/f124bfe619e72fc1c5f9abbd018bf2ee129f131bf2ede5ebcc
#   Building wheel for ibm-cos-sdk-s3transfer (setup.py): started
#   Building wheel for ibm-cos-sdk-s3transfer (setup.py): finished with status 'done'
#   Created wheel for ibm-cos-sdk-s3transfer: filename=ibm_cos_sdk_s3transfer-2.6.2-py2.py3-none-any.whl size=88602 sha256=14b1002df1f7c5ceeb573480349e88a326574580ef84746b1911841259aca57d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nrqteu2j/wheels/49/c8/20/8139a0a66f56909d5e96bfa423067020e6b5736c3a5b53f51c
#   Building wheel for googleapis-common-protos (setup.py): started
#   Building wheel for googleapis-common-protos (setup.py): finished with status 'done'
#   Created wheel for googleapis-common-protos: filename=googleapis_common_protos-1.51.0-cp36-none-any.whl size=77593 sha256=b6c77c487115b2c7e498b546d315bf06fea94e34645e830b3ce0b745b1a46905
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nrqteu2j/wheels/2c/f9/7f/6eb87e636072bf467e25348bbeb96849333e6a080dca78f706
#   Building wheel for pandocfilters (setup.py): started
#   Building wheel for pandocfilters (setup.py): finished with status 'done'
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.2-cp36-none-any.whl size=7856 sha256=802b3260448af5d4ea915f3b16903070f7b7d43d492093ba8458d93c4622a393
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nrqteu2j/wheels/39/01/56/f1b08a6275acc59e846fa4c1e1b65dbc1919f20157d9e66c20
#   Building wheel for backcall (setup.py): started
#   Building wheel for backcall (setup.py): finished with status 'done'
#   Created wheel for backcall: filename=backcall-0.1.0-cp36-none-any.whl size=10411 sha256=16125d1f8d3fd17c8f4472bf0227dc89eea38eaf5ec5a6c9bcd8c16745e27f10
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nrqteu2j/wheels/98/b0/dd/29e28ff615af3dda4c67cab719dd51357597eabff926976b45
#   Building wheel for pyrsistent (setup.py): started
#   Building wheel for pyrsistent (setup.py): finished with status 'done'
#   Created wheel for pyrsistent: filename=pyrsistent-0.16.0-cp36-cp36m-linux_x86_64.whl size=123221 sha256=0a84fe7a3b0993ce99b121706c96e1ed5563e8f4bbad4588d7944e7d20a1b9fa
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nrqteu2j/wheels/c2/85/ad/bc6d41e2c4b35c9fdfed48f0fcd411ffc4164e67755ddf9ebb
# Successfully built tornado prometheus-client jaeger-client Flask-OpenTracing opentracing termcolor absl-py pyyaml future retrying ibm-cos-sdk threadloop thrift ibm-cos-sdk-core ibm-cos-sdk-s3transfer googleapis-common-protos pandocfilters backcall pyrsistent
# ERROR: jaeger-client 4.1.0 has requirement tornado<6,>=4.3, but you'll have tornado 6.0.4 which is incompatible.
# ERROR: azure-mgmt 4.0.0 has requirement azure-mgmt-storage~=2.0, but you'll have azure-mgmt-storage 9.0.0 which is incompatible.
# ERROR: azure-storage-file 1.4.0 has requirement azure-storage-common~=1.4, but you'll have azure-storage-common 2.1.0 which is incompatible.
# ERROR: azure-storage-queue 1.4.0 has requirement azure-storage-common~=1.4, but you'll have azure-storage-common 2.1.0 which is incompatible.
# ERROR: azure 4.0.0 has requirement azure-storage-blob~=1.3, but you'll have azure-storage-blob 2.1.0 which is incompatible.
# ERROR: kubeflow-fairing 0.7.2 has requirement azure-storage-file>=2.1.0, but you'll have azure-storage-file 1.4.0 which is incompatible.
# ERROR: kubeflow-fairing 0.7.2 has requirement python-dateutil<=2.8.0,>=2.1, but you'll have python-dateutil 2.8.1 which is incompatible.
# ERROR: kubeflow-fairing 0.7.2 has requirement requests<2.23,>=2.21.0, but you'll have requests 2.23.0 which is incompatible.
# ERROR: kubeflow-fairing 0.7.2 has requirement urllib3==1.24.2, but you'll have urllib3 1.25.9 which is incompatible.
# Installing collected packages: cloudpickle, six, python-dateutil, numpy, pytz, pandas, joblib, scipy, scikit-learn, imbalanced-learn, imblearn, prometheus-client, opentracing, grpcio, grpcio-opentracing, gunicorn, tornado, threadloop, thrift, jaeger-client, configparser, certifi, urllib3, minio, chardet, idna, requests, pycparser, cffi, cryptography, azure-common, azure-storage-common, azure-storage-blob, flatbuffers, pyyaml, pyaml, Werkzeug, itsdangerous, click, MarkupSafe, Jinja2, Flask, Flask-cors, Flask-OpenTracing, protobuf, redis, seldon-core, gast, keras-preprocessing, h5py, keras-applications, astor, absl-py, markdown, tensorboard, mock, tensorflow-estimator, termcolor, tensorflow, keras, googleapis-common-protos, pyasn1, rsa, cachetools, pyasn1-modules, google-auth, google-api-core, google-cloud-core, google-resumable-media, google-cloud-storage, oauthlib, requests-oauthlib, websocket-client, kubernetes, table-logger, kubeflow-tfjob, azure-nspkg, isodate, msrest, PyJWT, adal, msrestazure, azure-batch
# , azure-mgmt-nspkg, azure-mgmt-monitor, azure-mgmt-hanaonazure, azure-mgmt-media, azure-mgmt-recoveryservices, azure-mgmt-datamigration, azure-mgmt-rdbms, azure-mgmt-storage, azure-mgmt-consumption, azure-mgmt-loganalytics, azure-mgmt-servicefabric, azure-mgmt-advisor, azure-mgmt-maps, azure-mgmt-managementgroups, azure-mgmt-iotcentral, azure-mgmt-containerinstance, azure-mgmt-containerservice, azure-mgmt-containerregistry, azure-mgmt-logic, azure-mgmt-web, azure-mgmt-scheduler, azure-mgmt-servicebus, azure-mgmt-dns, azure-mgmt-authorization, azure-mgmt-machinelearningcompute, azure-mgmt-devtestlabs, azure-mgmt-batchai, azure-mgmt-iothub, azure-mgmt-msi, azure-mgmt-datalake-nspkg, azure-mgmt-datalake-analytics, azure-mgmt-trafficmanager, azure-mgmt-resource, azure-mgmt-network, azure-mgmt-billing, azure-mgmt-batch, azure-mgmt-reservations, azure-mgmt-powerbiembedded, azure-mgmt-commerce, azure-mgmt-datalake-store, azure-mgmt-devspaces, azure-mgmt-applicationinsights, azure-mgmt-cdn, azure-mgmt-cosmosdb, azure
# -mgmt-datafactory, azure-mgmt-keyvault, azure-mgmt-managementpartner, azure-mgmt-iothubprovisioningservices, azure-mgmt-eventgrid, azure-mgmt-cognitiveservices, azure-mgmt-eventhub, azure-mgmt-redis, azure-mgmt-policyinsights, azure-mgmt-signalr, azure-mgmt-subscription, azure-mgmt-search, azure-mgmt-sql, azure-mgmt-marketplaceordering, azure-mgmt-recoveryservicesbackup, azure-mgmt-relay, azure-mgmt-compute, azure-mgmt-notificationhubs, azure-mgmt, azure-servicemanagement-legacy, azure-loganalytics, azure-datalake-store, azure-graphrbac, azure-storage-file, azure-servicebus, azure-applicationinsights, azure-eventgrid, azure-cosmosdb-nspkg, azure-cosmosdb-table, azure-storage-queue, azure-keyvault, azure-servicefabric, azure, jmespath, docutils, botocore, s3transfer, boto3, future, httplib2, google-auth-httplib2, uritemplate, google-api-python-client, retrying, google-cloud-logging, kubeflow-pytorchjob, argparse, kfserving, ipython-genutils, decorator, traitlets, jupyter-core, ptyprocess, terminado, pyzmq, jup
# yter-client, pickleshare, pygments, pexpect, parso, jedi, backcall, wcwidth, prompt-toolkit, ipython, ipykernel, webencodings, pyparsing, packaging, bleach, defusedxml, mistune, zipp, importlib-metadata, attrs, pyrsistent, jsonschema, nbformat, pandocfilters, testpath, entrypoints, nbconvert, Send2Trash, notebook, docker, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer, ibm-cos-sdk, oauth2client, kubeflow-fairing
# Successfully installed Flask-1.1.2 Flask-OpenTracing-1.1.0 Flask-cors-3.0.8 Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 Send2Trash-1.5.0 Werkzeug-1.0.1 absl-py-0.9.0 adal-1.2.2 argparse-1.4.0 astor-0.8.1 attrs-19.3.0 azure-4.0.0 azure-applicationinsights-0.1.0 azure-batch-4.1.3 azure-common-1.1.25 azure-cosmosdb-nspkg-2.0.2 azure-cosmosdb-table-1.0.6 azure-datalake-store-0.0.48 azure-eventgrid-1.3.0 azure-graphrbac-0.40.0 azure-keyvault-1.1.0 azure-loganalytics-0.1.0 azure-mgmt-4.0.0 azure-mgmt-advisor-1.0.1 azure-mgmt-applicationinsights-0.1.1 azure-mgmt-authorization-0.50.0 azure-mgmt-batch-5.0.1 azure-mgmt-batchai-2.0.0 azure-mgmt-billing-0.2.0 azure-mgmt-cdn-3.1.0 azure-mgmt-cognitiveservices-3.0.0 azure-mgmt-commerce-1.0.1 azure-mgmt-compute-4.6.2 azure-mgmt-consumption-2.0.0 azure-mgmt-containerinstance-1.5.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-containerservice-4.4.0 azure-mgmt-cosmosdb-0.4.1 azure-mgmt-datafactory-0.6.0 azure-mgmt-datalake-analytics-0.6.0 azure-mgmt-datalake-nspkg-3.0.1 azure-
# mgmt-datalake-store-0.5.0 azure-mgmt-datamigration-1.0.0 azure-mgmt-devspaces-0.1.0 azure-mgmt-devtestlabs-2.2.0 azure-mgmt-dns-2.1.0 azure-mgmt-eventgrid-1.0.0 azure-mgmt-eventhub-2.6.0 azure-mgmt-hanaonazure-0.1.1 azure-mgmt-iotcentral-0.1.0 azure-mgmt-iothub-0.5.0 azure-mgmt-iothubprovisioningservices-0.2.0 azure-mgmt-keyvault-1.1.0 azure-mgmt-loganalytics-0.2.0 azure-mgmt-logic-3.0.0 azure-mgmt-machinelearningcompute-0.4.1 azure-mgmt-managementgroups-0.1.0 azure-mgmt-managementpartner-0.1.1 azure-mgmt-maps-0.1.0 azure-mgmt-marketplaceordering-0.1.0 azure-mgmt-media-1.0.0 azure-mgmt-monitor-0.5.2 azure-mgmt-msi-0.2.0 azure-mgmt-network-2.7.0 azure-mgmt-notificationhubs-2.1.0 azure-mgmt-nspkg-3.0.2 azure-mgmt-policyinsights-0.1.0 azure-mgmt-powerbiembedded-2.0.0 azure-mgmt-rdbms-1.9.0 azure-mgmt-recoveryservices-0.3.0 azure-mgmt-recoveryservicesbackup-0.3.0 azure-mgmt-redis-5.0.0 azure-mgmt-relay-0.1.0 azure-mgmt-reservations-0.2.1 azure-mgmt-resource-2.2.0 azure-mgmt-scheduler-2.0.0 azure-mgmt-search-2.1.0
#  azure-mgmt-servicebus-0.5.3 azure-mgmt-servicefabric-0.2.0 azure-mgmt-signalr-0.1.1 azure-mgmt-sql-0.9.1 azure-mgmt-storage-9.0.0 azure-mgmt-subscription-0.2.0 azure-mgmt-trafficmanager-0.50.0 azure-mgmt-web-0.35.0 azure-nspkg-3.0.2 azure-servicebus-0.21.1 azure-servicefabric-6.3.0.0 azure-servicemanagement-legacy-0.20.6 azure-storage-blob-2.1.0 azure-storage-common-2.1.0 azure-storage-file-1.4.0 azure-storage-queue-1.4.0 backcall-0.1.0 bleach-3.1.5 boto3-1.12.49 botocore-1.15.49 cachetools-4.1.0 certifi-2020.4.5.1 cffi-1.14.0 chardet-3.0.4 click-7.1.2 cloudpickle-1.1.1 configparser-5.0.0 cryptography-2.9.2 decorator-4.4.2 defusedxml-0.6.0 docker-4.2.0 docutils-0.15.2 entrypoints-0.3 flatbuffers-1.12 future-0.18.2 gast-0.3.3 google-api-core-1.17.0 google-api-python-client-1.8.2 google-auth-1.14.1 google-auth-httplib2-0.0.3 google-cloud-core-1.3.0 google-cloud-logging-1.15.0 google-cloud-storage-1.28.0 google-resumable-media-0.5.0 googleapis-common-protos-1.51.0 grpcio-1.28.1 grpcio-opentracing-1.1.4 gunicorn
# -20.0.4 h5py-2.10.0 httplib2-0.17.3 ibm-cos-sdk-2.6.2 ibm-cos-sdk-core-2.6.2 ibm-cos-sdk-s3transfer-2.6.2 idna-2.9 imbalanced-learn-0.6.2 imblearn-0.0 importlib-metadata-1.6.0 ipykernel-5.2.1 ipython-7.13.0 ipython-genutils-0.2.0 isodate-0.6.0 itsdangerous-1.1.0 jaeger-client-4.1.0 jedi-0.17.0 jmespath-0.9.5 joblib-0.14.1 jsonschema-3.2.0 jupyter-client-6.1.3 jupyter-core-4.6.3 keras-2.2.4 keras-applications-1.0.8 keras-preprocessing-1.1.0 kfserving-0.3.0.1 kubeflow-fairing-0.7.2 kubeflow-pytorchjob-0.1.3 kubeflow-tfjob-0.1.3 kubernetes-10.0.1 markdown-3.2.1 minio-5.0.10 mistune-0.8.4 mock-4.0.2 msrest-0.6.13 msrestazure-0.6.3 nbconvert-5.6.1 nbformat-5.0.6 notebook-6.0.3 numpy-1.18.3 oauth2client-4.1.3 oauthlib-3.1.0 opentracing-2.2.0 packaging-20.3 pandas-1.0.3 pandocfilters-1.4.2 parso-0.7.0 pexpect-4.8.0 pickleshare-0.7.5 prometheus-client-0.7.1 prompt-toolkit-3.0.5 protobuf-3.11.3 ptyprocess-0.6.0 pyaml-19.12.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.20 pygments-2.6.1 pyparsing-2.4.7 pyrsistent-0.1
# 6.0 python-dateutil-2.8.1 pytz-2020.1 pyyaml-5.3.1 pyzmq-19.0.0 redis-3.5.0 requests-2.23.0 requests-oauthlib-1.3.0 retrying-1.3.3 rsa-4.0 s3transfer-0.3.3 scikit-learn-0.22.2 scipy-1.4.1 seldon-core-1.1.0 six-1.14.0 table-logger-0.3.6 tensorboard-1.13.1 tensorflow-1.13.1 tensorflow-estimator-1.13.0 termcolor-1.1.0 terminado-0.8.3 testpath-0.4.4 threadloop-1.0.2 thrift-0.13.0 tornado-6.0.4 traitlets-4.3.3 uritemplate-3.0.1 urllib3-1.25.9 wcwidth-0.1.9 webencodings-0.5.1 websocket-client-0.57.0 zipp-3.1.0
# WARNING: You are using pip version 19.3.1; however, version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# INFO[0115] Taking snapshot of full filesystem...
# INFO[0175] Using files from context: [/kaniko/buildcontext/app]
# INFO[0176] COPY /app/ /app/
# INFO[0176] Taking snapshot of files...
# The job fairing-job-bmhl2 launched.
# Waiting for fairing-job-bmhl2-gv6kt to start...
# Waiting for fairing-job-bmhl2-gv6kt to start...
# Waiting for fairing-job-bmhl2-gv6kt to start...
# Waiting for fairing-job-bmhl2-gv6kt to start...
# Pod started running True
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Cleaning up job fairing-job-bmhl2...
# 'fairing-job-bmhl2'

# %% [markdown]
# ## Deploy the trained model to Kubeflow for predictions
# Kubeflow Fairing packages the NetworkServe class, the trained model, and the prediction endpoint's software prerequisites as a Docker image. Then Kubeflow Fairing deploys and runs the prediction endpoint on Kubeflow.

# %%
endpoint = PredictionEndpoint(NetworkServe, input_files=["Network_Traffic.csv", "requirements.txt"],
                              docker_registry=DOCKER_REGISTRY,
                              pod_spec_mutators = [mounting_pvc(pvc_name="nfs1", pvc_mount_path="/mnt/Model_Network")],
                              backend=BackendClass(build_context_source=minio_context_source))
endpoint.create()
# Out:
# Using default base docker image: registry.hub.docker.com/library/python:3.6.9
# Using builder: <class 'kubeflow.fairing.builders.cluster.cluster.ClusterBuilder'>
# Building the docker image.
# Building image using cluster builder.
# /home/jovyan/.local/lib/python3.6/site-packages/kubeflow/fairing/__init__.py already exists in Fairing context, skipping...
# Creating docker context: /tmp/fairing_context_pg0en7wg
# /home/jovyan/.local/lib/python3.6/site-packages/kubeflow/fairing/__init__.py already exists in Fairing context, skipping...
# Waiting for fairing-builder-2s879-n9b2q to start...
# Waiting for fairing-builder-2s879-n9b2q to start...
# Waiting for fairing-builder-2s879-n9b2q to start...
# Waiting for fairing-builder-2s879-n9b2q to start...
# Pod started running True
# INFO[0003] Resolved base name registry.hub.docker.com/library/python:3.6.9 to registry.hub.docker.com/library/python:3.6.9
# INFO[0003] Resolved base name registry.hub.docker.com/library/python:3.6.9 to registry.hub.docker.com/library/python:3.6.9
# INFO[0003] Downloading base image registry.hub.docker.com/library/python:3.6.9
# INFO[0004] Error while retrieving image from cache: getting file info: stat /cache/sha256:036d4ab50fa49df89e746cf1b5369c88db46e8af2fbd08531788e7d920e9a491: no such file or directory
# INFO[0004] Downloading base image registry.hub.docker.com/library/python:3.6.9
# INFO[0005] Built cross stage deps: map[]
# INFO[0005] Downloading base image registry.hub.docker.com/library/python:3.6.9
# INFO[0006] Error while retrieving image from cache: getting file info: stat /cache/sha256:036d4ab50fa49df89e746cf1b5369c88db46e8af2fbd08531788e7d920e9a491: no such file or directory
# INFO[0006] Downloading base image registry.hub.docker.com/library/python:3.6.9
# INFO[0007] Unpacking rootfs as cmd COPY /app//requirements.txt /app/ requires it.
# INFO[0023] Taking snapshot of full filesystem...
# INFO[0030] WORKDIR /app/
# INFO[0030] cmd: workdir
# INFO[0030] Changed working directory to /app/
# INFO[0030] Creating directory /app/
# INFO[0030] Taking snapshot of files...
# INFO[0030] ENV FAIRING_RUNTIME 1
# INFO[0030] Using files from context: [/kaniko/buildcontext/app/requirements.txt]
# INFO[0030] COPY /app//requirements.txt /app/
# INFO[0030] Taking snapshot of files...
# INFO[0030] RUN if [ -e requirements.txt ];then pip install --no-cache -r requirements.txt; fi
# INFO[0030] cmd: /bin/sh
# INFO[0030] args: [-c if [ -e requirements.txt ];then pip install --no-cache -r requirements.txt; fi]
# Collecting cloudpickle==1.1.1
#   Downloading https://files.pythonhosted.org/packages/24/fb/4f92f8c0f40a0d728b4f3d5ec5ff84353e705d8ff5e3e447620ea98b06bd/cloudpickle-1.1.1-py2.py3-none-any.whl
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/bb/71/8f53bdbcbc67c912b888b40def255767e475402e9df64050019149b1a943/pandas-1.0.3-cp36-cp36m-manylinux1_x86_64.whl (10.0MB)
# Collecting scikit-learn==0.22.2
#   Downloading https://files.pythonhosted.org/packages/e1/7f/366dcba1ba076a88a50bea732dbc033c0c5bbf7876010e6edc67948579d5/scikit_learn-0.22.2-cp36-cp36m-manylinux1_x86_64.whl (7.1MB)
# Collecting imblearn
#   Downloading https://files.pythonhosted.org/packages/81/a7/4179e6ebfd654bd0eac0b9c06125b8b4c96a9d0a8ff9e9507eb2a26d2d7e/imblearn-0.0-py2.py3-none-any.whl
# Collecting joblib
#   Downloading https://files.pythonhosted.org/packages/28/5c/cf6a2b65a321c4a209efcdf64c2689efae2cb62661f8f6f4bb28547cf1bf/joblib-0.14.1-py2.py3-none-any.whl (294kB)
# Collecting numpy
#   Downloading https://files.pythonhosted.org/packages/3d/fc/4763e5f17ac6e7e7d55f377cde859ca1c5d5ac624441ab45315bc578aa9e/numpy-1.18.3-cp36-cp36m-manylinux1_x86_64.whl (20.2MB)
# Collecting seldon-core
#   Downloading https://files.pythonhosted.org/packages/a5/a5/81f818dc216fa9a43aa195ac3d0cfaa9a7991707161b9faf8bc0dbe5022c/seldon_core-1.1.0-py3-none-any.whl (94kB)
# Collecting tornado>=6.0.3
#   Downloading https://files.pythonhosted.org/packages/95/84/119a46d494f008969bf0c775cb2c6b3579d3c4cc1bb1b41a022aa93ee242/tornado-6.0.4.tar.gz (496kB)
# Collecting tensorflow==1.13.1
#   Downloading https://files.pythonhosted.org/packages/77/63/a9fa76de8dffe7455304c4ed635be4aa9c0bacef6e0633d87d5f54530c5c/tensorflow-1.13.1-cp36-cp36m-manylinux1_x86_64.whl (92.5MB)
# Collecting keras==2.2.4
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
# Collecting google-cloud-storage
#   Downloading https://files.pythonhosted.org/packages/85/47/c3ab1b34d2448de71a39f64534b4fb5bb76ed5694370a20a45627de7372d/google_cloud_storage-1.28.0-py2.py3-none-any.whl (80kB)
# Collecting kubeflow-tfjob
#   Downloading https://files.pythonhosted.org/packages/67/09/ae7e4a13cf68ed4a99b050b798611d27744b8a99e674e16098f15609c6ff/kubeflow_tfjob-0.1.3-py3-none-any.whl (46kB)
# Collecting azure==4.0.0
#   Downloading https://files.pythonhosted.org/packages/5a/5e/f94bd8091ab0ccc68ee902e188d4e8cd3b38dc77155a1c187cbf4767d0e4/azure-4.0.0-py2.py3-none-any.whl
# Collecting kubeflow-fairing
#   Downloading https://files.pythonhosted.org/packages/d6/69/7910a26ad3f4647988ab2e415b18a50899aa78d05daf8975aa3722308c82/kubeflow_fairing-0.7.2-py3-none-any.whl (160kB)
# Collecting kubernetes==10.0.1
#   Downloading https://files.pythonhosted.org/packages/6e/fc/2cab119f679648b348b8940de0dd744a1f0ee99c690aa2ef6072f050816c/kubernetes-10.0.1-py2.py3-none-any.whl (1.5MB)
# Collecting python-dateutil>=2.6.1
#   Downloading https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl (227kB)
# Collecting pytz>=2017.2
#   Downloading https://files.pythonhosted.org/packages/4f/a4/879454d49688e2fad93e59d7d4efda580b783c745fd2ec2a3adf87b0808d/pytz-2020.1-py2.py3-none-any.whl (510kB)
# Collecting scipy>=0.17.0
#   Downloading https://files.pythonhosted.org/packages/dc/29/162476fd44203116e7980cfbd9352eef9db37c49445d1fec35509022f6aa/scipy-1.4.1-cp36-cp36m-manylinux1_x86_64.whl (26.1MB)
# Collecting imbalanced-learn
#   Downloading https://files.pythonhosted.org/packages/c8/73/36a13185c2acff44d601dc6107b5347e075561a49e15ddd4e69988414c3e/imbalanced_learn-0.6.2-py3-none-any.whl (163kB)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/site-packages (from seldon-core->-r requirements.txt (line 7)) (41.6.0)
# Collecting prometheus-client<0.8.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/b3/23/41a5a24b502d35a4ad50a5bb7202a5e1d9a0364d0c12f56db3dbf7aca76d/prometheus_client-0.7.1.tar.gz
# Collecting requests<3.0.0
#   Downloading https://files.pythonhosted.org/packages/1a/70/1935c770cb3be6e3a8b78ced23d7e0f3b187f5cbfab4749523ed65d7c9b1/requests-2.23.0-py2.py3-none-any.whl (58kB)
# Collecting jaeger-client<4.2.0,>=4.1.0
#   Downloading https://files.pythonhosted.org/packages/f1/da/569a4f1bc3d0c412c7f903053f09ef62fa10949374ca90bc852b22dd3860/jaeger-client-4.1.0.tar.gz (80kB)
# Collecting pyaml<20.0.0
#   Downloading https://files.pythonhosted.org/packages/35/1e/eda9fe07f752ced7afcef590e7d74390f0d9c9c0b7ff98317afbaa0697e3/pyaml-19.12.0-py2.py3-none-any.whl
# Collecting minio<6.0.0,>=4.0.9
#   Downloading https://files.pythonhosted.org/packages/aa/60/81f4a1dc2d320832840288d7ec88aa3e4ee495d8f1452b4c79d8bd67136b/minio-5.0.10-py2.py3-none-any.whl (75kB)
# Collecting grpcio-opentracing<1.2.0,>=1.1.4
#   Downloading https://files.pythonhosted.org/packages/db/82/2fcad380697c3dab25de76ee590bcab3eb9bbfb4add916044d7e83ec2b10/grpcio_opentracing-1.1.4-py3-none-any.whl
# Collecting gunicorn<20.1.0,>=19.9.0
#   Downloading https://files.pythonhosted.org/packages/69/ca/926f7cd3a2014b16870086b2d0fdc84a9e49473c68a8dff8b57f7c156f43/gunicorn-20.0.4-py2.py3-none-any.whl (77kB)
# Collecting protobuf<4.0.0
#   Downloading https://files.pythonhosted.org/packages/57/02/5432412c162989260fab61fa65e0a490c1872739eb91a659896e4d554b26/protobuf-3.11.3-cp36-cp36m-manylinux1_x86_64.whl (1.3MB)
# Collecting azure-storage-blob<3.0.0,>=2.0.1
#   Downloading https://files.pythonhosted.org/packages/3e/84/610f379b46d7d3c2d48eadeed6a12b6d46a43100fea70534f5992d0ac996/azure_storage_blob-2.1.0-py2.py3-none-any.whl (88kB)
# Collecting flatbuffers<2.0.0
#   Downloading https://files.pythonhosted.org/packages/eb/26/712e578c5f14e26ae3314c39a1bdc4eb2ec2f4ddc89b708cf8e0a0d20423/flatbuffers-1.12-py2.py3-none-any.whl
# Collecting Flask-cors<4.0.0
#   Downloading https://files.pythonhosted.org/packages/78/38/e68b11daa5d613e3a91e4bf3da76c94ac9ee0d9cd515af9c1ab80d36f709/Flask_Cors-3.0.8-py2.py3-none-any.whl
# Collecting opentracing<2.3.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/94/9f/289424136addf621fb4c75624ef9a3a80e8575da3993a87950c57e93217e/opentracing-2.2.0.tar.gz (47kB)
# Collecting redis<4.0.0
#   Downloading https://files.pythonhosted.org/packages/d2/07/20cb8df2ded4b5db176a65da48b7c8d4295d868776296580b11071218a2b/redis-3.5.0-py2.py3-none-any.whl (71kB)
# Collecting Flask-OpenTracing<1.2.0,>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/58/6c/6417701ba5ecc8854670c6db3207bcc3e5fbc96289a7cb18d5516d99a1c6/Flask-OpenTracing-1.1.0.tar.gz
# Collecting Flask<2.0.0
#   Downloading https://files.pythonhosted.org/packages/f2/28/2a03252dfb9ebf377f40fba6a7841b47083260bf8bd8e737b0c6952df83f/Flask-1.1.2-py2.py3-none-any.whl (94kB)
# Collecting grpcio<2.0.0
#   Downloading https://files.pythonhosted.org/packages/f3/97/f74da84d4db8cfe95f9b6aa2469be79af1873fec1adb80405105ed99a0a8/grpcio-1.28.1-cp36-cp36m-manylinux2010_x86_64.whl (2.8MB)
# Collecting keras-preprocessing>=1.0.5
#   Downloading https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41kB)
# Collecting six>=1.10.0
#   Downloading https://files.pythonhosted.org/packages/65/eb/1f97cb97bfc2390a276969c6fae16075da282f5058082d4cb10c6c5c1dba/six-1.14.0-py2.py3-none-any.whl
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
# Collecting astor>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/c3/88/97eef84f48fa04fbd6750e62dcceafba6c63c81b7ac1420856c8dcc0a3f9/astor-0.8.1-py2.py3-none-any.whl
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/site-packages (from tensorflow==1.13.1->-r requirements.txt (line 9)) (0.33.6)
# Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/bb/48/13f49fc3fa0fdf916aa1419013bb8f2ad09674c275b4046d5ee669a46873/tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367kB)
# Collecting absl-py>=0.1.6
#   Downloading https://files.pythonhosted.org/packages/1a/53/9243c600e047bd4c3df9e69cfabc1e8004a82cac2e0c484580a78a94ba2a/absl-py-0.9.0.tar.gz (104kB)
# Collecting gast>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/d6/84/759f5dd23fec8ba71952d97bcc7e2c9d7d63bdc582421f3cd4be845f0c98/gast-0.3.3-py2.py3-none-any.whl
# Collecting tensorboard<1.14.0,>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/0f/39/bdd75b08a6fba41f098b6cb091b9e8c7a80e1b4d679a581a0ccd17b10373/tensorboard-1.13.1-py3-none-any.whl (3.2MB)
# Collecting termcolor>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Collecting h5py
#   Downloading https://files.pythonhosted.org/packages/60/06/cafdd44889200e5438b897388f3075b52a8ef01f28a17366d91de0fa2d05/h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl (2.9MB)
# Collecting pyyaml
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
# Collecting google-auth<2.0dev,>=1.11.0
#   Downloading https://files.pythonhosted.org/packages/d2/f8/1623d69e5de22e499b68a0cb5e5d02cd6a2843e55acc19f314f48fe04299/google_auth-1.14.1-py2.py3-none-any.whl (89kB)
# Collecting google-cloud-core<2.0dev,>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/89/3c/8a7531839028c9690e6d14c650521f3bbaf26e53baaeb2784b8c3eb2fb97/google_cloud_core-1.3.0-py2.py3-none-any.whl
# Collecting google-resumable-media<0.6dev,>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/35/9e/f73325d0466ce5bdc36333f1aeb2892ead7b76e79bdb5c8b0493961fa098/google_resumable_media-0.5.0-py2.py3-none-any.whl
# Collecting table-logger>=0.3.5
#   Downloading https://files.pythonhosted.org/packages/0d/80/d4e0e9005caccae0185d4919844792a9227ebf4ed8e431c13625556b8c74/table_logger-0.3.6-py3-none-any.whl
# Collecting urllib3>=1.15.1
#   Downloading https://files.pythonhosted.org/packages/e1/e5/df302e8017440f111c11cc41a6b432838672f5a70aa29227bf58149dc72f/urllib3-1.25.9-py2.py3-none-any.whl (126kB)
# Collecting certifi>=14.05.14
#   Downloading https://files.pythonhosted.org/packages/57/2b/26e37a4b034800c960a00c4e1b3d9ca5d7014e983e6e729e33ea2f36426c/certifi-2020.4.5.1-py2.py3-none-any.whl (157kB)
# Collecting azure-mgmt~=4.0
#   Downloading https://files.pythonhosted.org/packages/19/8e/6fa401c437579127e726487582a9861fef09022c4ab50901bb499a8e4fc1/azure_mgmt-4.0.0-py2.py3-none-any.whl
# Collecting azure-cosmosdb-table~=1.0
#   Downloading https://files.pythonhosted.org/packages/f0/e4/15a59108883cc47460b1475aeac935e2d975b5def42f2c0a8b8fd48b3304/azure_cosmosdb_table-1.0.6-py2.py3-none-any.whl (125kB)
# Collecting azure-loganalytics~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/54/e2/1d30270441a50efce1d52eb426710fc98269eb8bdac44ee966bbd07846da/azure_loganalytics-0.1.0-py2.py3-none-any.whl
# Collecting azure-servicefabric~=6.3.0.0
#   Downloading https://files.pythonhosted.org/packages/2c/d9/3e33ad19eb57988dff3aac06bab241736f86dc692a38c5ff6bb6fb959243/azure_servicefabric-6.3.0.0-py2.py3-none-any.whl (1.1MB)
# Collecting azure-storage-queue~=1.3
#   Downloading https://files.pythonhosted.org/packages/72/94/4db044f1c155b40c5ebc037bfd9d1c24562845692c06798fbe869fe160e6/azure_storage_queue-1.4.0-py2.py3-none-any.whl
# Collecting azure-servicebus~=0.21.1
#   Downloading https://files.pythonhosted.org/packages/b8/de/47c0df32b57512ac9640ba239c7eeca22cb908bd8b645235729ec4f37196/azure_servicebus-0.21.1-py2.py3-none-any.whl
# Collecting azure-batch~=4.1
#   Downloading https://files.pythonhosted.org/packages/b1/fa/1053b5dcd88e5de8e8cd70a4d7189ffad037542963ea86b518deb612c498/azure_batch-4.1.3-py2.py3-none-any.whl (314kB)
# Collecting azure-datalake-store~=0.0.18
#   Downloading https://files.pythonhosted.org/packages/27/9a/e7140775b3f8f011ef5d001c12a3519310094375671950105519e30bb12b/azure_datalake_store-0.0.48-py2.py3-none-any.whl (53kB)
# Collecting azure-eventgrid~=1.1
#   Downloading https://files.pythonhosted.org/packages/01/e4/2a3319f04c69f0113a05884664769d462dcec55031c6d154a2c4176cfb79/azure_eventgrid-1.3.0-py2.py3-none-any.whl (167kB)
# Collecting azure-keyvault~=1.0
#   Downloading https://files.pythonhosted.org/packages/80/37/e80f577570b32648c4b88c8c48a46501a4868ae4c8d905774fd02c2b01fc/azure_keyvault-1.1.0-py2.py3-none-any.whl (352kB)
# Collecting azure-storage-file~=1.3
#   Downloading https://files.pythonhosted.org/packages/c9/33/6c611563412ffc409b2413ac50e3a063133ea235b86c137759774c77f3ad/azure_storage_file-1.4.0-py2.py3-none-any.whl
# Collecting azure-servicemanagement-legacy~=0.20.6
#   Downloading https://files.pythonhosted.org/packages/a3/2b/0813d459df7ec04bb8c6a250882ee88b672a5f8d16a237978c89436a053e/azure_servicemanagement_legacy-0.20.6-py2.py3-none-any.whl (78kB)
# Collecting azure-applicationinsights~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/3b/f7/3af9ce8a9a597998629436889cf5d69d1a0c96713e795fd372e4af785635/azure_applicationinsights-0.1.0-py2.py3-none-any.whl (104kB)
# Collecting azure-graphrbac~=0.40.0
#   Downloading https://files.pythonhosted.org/packages/89/0a/29f7e2914033e2536026b8f0d7f8deb1edda68c9a93ce4757b2b1e39568b/azure_graphrbac-0.40.0-py2.py3-none-any.whl (63kB)
# Collecting notebook>=5.6.0
#   Downloading https://files.pythonhosted.org/packages/b1/f1/0a67f09ef53a342403ffa66646ee39273e0ac79ffa5de5dbe2f3e28b5bdf/notebook-6.0.3-py3-none-any.whl (9.7MB)
# Collecting future>=0.17.1
#   Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
# Collecting httplib2>=0.12.0
#   Downloading https://files.pythonhosted.org/packages/18/9b/b95a08c373819376bf3f109bdbcff6bd4f69f2340bf708a252380319037a/httplib2-0.17.3-py3-none-any.whl (95kB)
# Collecting oauth2client>=4.0.0
#   Downloading https://files.pythonhosted.org/packages/95/a9/4f25a14d23f0786b64875b91784607c2277eff25d48f915e39ff0cff505a/oauth2client-4.1.3-py2.py3-none-any.whl (98kB)
# Collecting kubeflow-pytorchjob>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/7e/73/8a8787a8cc99a67adec5fb858e12e3f51aeb546e3470a2fe0fdbc3a81f83/kubeflow_pytorchjob-0.1.3-py3-none-any.whl (46kB)
# Collecting kfserving>=0.2.1.1
#   Downloading https://files.pythonhosted.org/packages/8c/61/8d826af3f8554f520eb8f2b4716bab29a3d924098669554672d346e71b9b/kfserving-0.3.0.1-py3-none-any.whl (83kB)
# Collecting google-cloud-logging>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/57/75/2f5ade21f5c5bfd7cc5fb4ee9be26cdb19b9ee11cc6ea4b58656415d832f/google_cloud_logging-1.15.0-py2.py3-none-any.whl (141kB)
# Collecting retrying>=1.3.3
#   Downloading https://files.pythonhosted.org/packages/44/ef/beae4b4ef80902f22e3af073397f079c96969c69b2c7d52a57ea9ae61c9d/retrying-1.3.3.tar.gz
# Collecting boto3>=1.9.0
#   Downloading https://files.pythonhosted.org/packages/52/f6/20eee4b17af26e40a528cd4769d325bc48b0a3e614b6a92cb329417df31c/boto3-1.12.49-py2.py3-none-any.whl (128kB)
# Collecting docker>=3.4.1
#   Downloading https://files.pythonhosted.org/packages/58/74/379a9d30b1620def158c40b88c43e01c1936a287ebb97afab0699c601c57/docker-4.2.0-py2.py3-none-any.whl (143kB)
# Collecting azure-mgmt-storage>=9.0.0
#   Downloading https://files.pythonhosted.org/packages/65/f0/8486761674c640c48219824b3ccd3cc571a792d1a0e90c8d25ed0e202d8d/azure_mgmt_storage-9.0.0-py2.py3-none-any.whl (525kB)
# Collecting google-api-python-client>=1.7.8
#   Downloading https://files.pythonhosted.org/packages/6e/9c/e3da18a0126c4a2c0e43f824c8f8ad1c8e4afd25f3daf2b6baf7af5bd6a0/google_api_python_client-1.8.2-py3-none-any.whl (58kB)
# Collecting ibm-cos-sdk>=2.6.0
#   Downloading https://files.pythonhosted.org/packages/a0/08/2b5ff7a58a237c98f9b25cd24bab8ec4f8ccb86c1ebc625d1c922f6a5816/ibm-cos-sdk-2.6.2.tar.gz (54kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0
#   Downloading https://files.pythonhosted.org/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl (200kB)
# Collecting requests-oauthlib
#   Downloading https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Collecting chardet<4,>=3.0.2
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Collecting idna<3,>=2.5
#   Downloading https://files.pythonhosted.org/packages/89/e3/afebe61c546d18fb1709a61bee788254b40e736cff7271c7de5de2dc4128/idna-2.9-py2.py3-none-any.whl (58kB)
# Collecting threadloop<2,>=1
#   Downloading https://files.pythonhosted.org/packages/d3/1d/8398c1645b97dc008d3c658e04beda01ede3d90943d40c8d56863cf891bd/threadloop-1.0.2.tar.gz
# Collecting thrift
#   Downloading https://files.pythonhosted.org/packages/97/1e/3284d19d7be99305eda145b8aa46b0c33244e4a496ec66440dac19f8274d/thrift-0.13.0.tar.gz (59kB)
# Collecting configparser
#   Downloading https://files.pythonhosted.org/packages/4b/6b/01baa293090240cf0562cc5eccb69c6f5006282127f2b846fad011305c79/configparser-5.0.0-py3-none-any.whl
# Collecting azure-common>=1.1.5
#   Downloading https://files.pythonhosted.org/packages/e5/4d/d000fc3c5af601d00d55750b71da5c231fcb128f42ac95b208ed1091c2c1/azure_common-1.1.25-py2.py3-none-any.whl
# Collecting azure-storage-common~=2.1
#   Downloading https://files.pythonhosted.org/packages/6b/a0/6794b318ce0118d1a4053bdf0149a60807407db9b710354f2b203c2f5975/azure_storage_common-2.1.0-py2.py3-none-any.whl (47kB)
# Collecting click>=5.1
#   Downloading https://files.pythonhosted.org/packages/d2/3d/fa76db83bf75c4f8d338c2fd15c8d33fdd7ad23a9b5e57eb6c5de26b430e/click-7.1.2-py2.py3-none-any.whl (82kB)
# Collecting Jinja2>=2.10.1
#   Downloading https://files.pythonhosted.org/packages/30/9e/f663a2aa66a09d838042ae1a2c5659828bb9b41ea3a6efa20a20fd92b121/Jinja2-2.11.2-py2.py3-none-any.whl (125kB)
# Collecting Werkzeug>=0.15
#   Downloading https://files.pythonhosted.org/packages/cc/94/5f7079a0e00bd6863ef8f1da638721e9da21e5bacee597595b318f71d62e/Werkzeug-1.0.1-py2.py3-none-any.whl (298kB)
# Collecting itsdangerous>=0.24
#   Downloading https://files.pythonhosted.org/packages/76/ae/44b03b253d6fade317f32c24d100b3b35c2239807046a4c953c7b89fa49e/itsdangerous-1.1.0-py2.py3-none-any.whl
# Collecting mock>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/cd/74/d72daf8dff5b6566db857cfd088907bb0355f5dd2914c4b3ef065c790735/mock-4.0.2-py3-none-any.whl
# Collecting markdown>=2.6.8
#   Downloading https://files.pythonhosted.org/packages/ab/c4/ba46d44855e6eb1770a12edace5a165a0c6de13349f592b9036257f3c3d3/Markdown-3.2.1-py2.py3-none-any.whl (88kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/b3/59/524ffb454d05001e2be74c14745b485681c6ed5f2e625f71d135704c0909/cachetools-4.1.0-py3-none-any.whl
# Collecting rsa<4.1,>=3.1.4
#   Downloading https://files.pythonhosted.org/packages/02/e5/38518af393f7c214357079ce67a317307936896e961e35450b70fad2a9cf/rsa-4.0-py2.py3-none-any.whl
# Collecting pyasn1-modules>=0.2.1
#   Downloading https://files.pythonhosted.org/packages/95/de/214830a981892a3e286c3794f41ae67a4495df1108c3da8a9f62159b9a9d/pyasn1_modules-0.2.8-py2.py3-none-any.whl (155kB)
# Collecting google-api-core<2.0.0dev,>=1.16.0
#   Downloading https://files.pythonhosted.org/packages/4c/b9/c0dd70bcdf06a43d1e21f387448e7997e0ce91f10d0fbee359af4cde1571/google_api_core-1.17.0-py2.py3-none-any.whl (70kB)
# Collecting azure-mgmt-authorization~=0.50.0
#   Downloading https://files.pythonhosted.org/packages/6f/17/55b974603c16be89c7a7c16bac57b7bce48527bf1bebc3f116f7215176e6/azure_mgmt_authorization-0.50.0-py2.py3-none-any.whl (81kB)
# Collecting azure-mgmt-cognitiveservices~=3.0
#   Downloading https://files.pythonhosted.org/packages/8d/c8/222ea2f533c6b8f8656f3091101b4c3aa32c162d2a609d07d1ae00172515/azure_mgmt_cognitiveservices-3.0.0-py2.py3-none-any.whl (58kB)
# Collecting azure-mgmt-iothubprovisioningservices~=0.2.0
#   Downloading https://files.pythonhosted.org/packages/84/ce/3500c731a5c5b31028e662aa41bc45f75301834a0c03adeacfe7ef7bd86e/azure_mgmt_iothubprovisioningservices-0.2.0-py2.py3-none-any.whl (60kB)
# Collecting azure-mgmt-advisor~=1.0
#   Downloading https://files.pythonhosted.org/packages/cb/f3/a86ba3e0784d12c8fe5cbf1f24e1b9255575a2f0892e08c46cddd0795dfd/azure_mgmt_advisor-1.0.1-py2.py3-none-any.whl
# Collecting azure-mgmt-search~=2.0
#   Downloading https://files.pythonhosted.org/packages/c9/18/fa4e0d541332c0ba6ef16beaa9b55f831436949e7d0981d5677dff2ddfb5/azure_mgmt_search-2.1.0-py2.py3-none-any.whl (41kB)
# Collecting azure-mgmt-loganalytics~=0.2.0
#   Downloading https://files.pythonhosted.org/packages/70/40/c9b77bf82916e963aa701fb396673f7ddc4cdab95524b6d2edf927b05630/azure_mgmt_loganalytics-0.2.0-py2.py3-none-any.whl (89kB)
# Collecting azure-mgmt-marketplaceordering~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/a8/cb/13502fdbaf520d08fb280eb31ecfe5d926b9cf92259c22280bbde96b307d/azure_mgmt_marketplaceordering-0.1.0-py2.py3-none-any.whl
# Collecting azure-mgmt-billing~=0.2.0
#   Downloading https://files.pythonhosted.org/packages/0f/24/5106287ea0f6562d965afb055e3c6c0da058f7844a70464e67bab56c6c4b/azure_mgmt_billing-0.2.0-py2.py3-none-any.whl
# Collecting azure-mgmt-iotcentral~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/58/4e/e2e5f2d545a46ada3705c85c45c12882a443d40f60e1a908c78058e15cf2/azure_mgmt_iotcentral-0.1.0-py2.py3-none-any.whl
# Collecting azure-mgmt-scheduler~=2.0
#   Downloading https://files.pythonhosted.org/packages/e8/55/f3490698ff622244438e667e0321808e84389e69c5fb77a1d6db869d9bb7/azure_mgmt_scheduler-2.0.0-py2.py3-none-any.whl (67kB)
# Collecting azure-mgmt-keyvault~=1.0
#   Downloading https://files.pythonhosted.org/packages/49/de/0d69aedae7c5f6428314640b65947203ab80409c12b5d4e66fb5b7a4182e/azure_mgmt_keyvault-1.1.0-py2.py3-none-any.whl (111kB)
# Collecting azure-mgmt-eventgrid~=1.0
#   Downloading https://files.pythonhosted.org/packages/54/5b/e91e616021ae9be0019c9c19cffb92b97d787246ca51cfcc0b0a0c6da77a/azure_mgmt_eventgrid-1.0.0-py2.py3-none-any.whl (51kB)
# Collecting azure-mgmt-maps~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/e4/04/c64326729e842f3eab1fd527f7582e269e4b0e5b9324a4562edaf0371953/azure_mgmt_maps-0.1.0-py2.py3-none-any.whl
# Collecting azure-mgmt-servicefabric~=0.2.0
#   Downloading https://files.pythonhosted.org/packages/6e/06/fafe8b5d881cfa68927e61557c8419dcfacb93e07f4ab17cc60959707a53/azure_mgmt_servicefabric-0.2.0-py2.py3-none-any.whl (142kB)
# Collecting azure-mgmt-rdbms~=1.2
#   Downloading https://files.pythonhosted.org/packages/d2/94/c850c8257d19b08eb6b03154d6fe21938801562b4082d27985f54ebe9de4/azure_mgmt_rdbms-1.9.0-py2.py3-none-any.whl (259kB)
# Collecting azure-mgmt-iothub~=0.5.0
#   Downloading https://files.pythonhosted.org/packages/19/d6/b422df467b3d7f4e2975b590fbf6e12aaae0a497c7d080b4955a6a6d794a/azure_mgmt_iothub-0.5.0-py2.py3-none-any.whl (102kB)
# Collecting azure-mgmt-datafactory~=0.6.0
#   Downloading https://files.pythonhosted.org/packages/cf/01/32a6ad5ad348d965f7c106d819a1f6dc613f6aa98a720ffc529ef468016b/azure_mgmt_datafactory-0.6.0-py2.py3-none-any.whl (418kB)
# Collecting azure-mgmt-datamigration~=1.0
#   Downloading https://files.pythonhosted.org/packages/8b/4f/7b149487e77d94e701288e1d0b066a7d522bdfe8595e992b5d39dfb00f80/azure_mgmt_datamigration-1.0.0-py2.py3-none-any.whl (185kB)
# Collecting azure-mgmt-recoveryservicesbackup~=0.3.0
#   Downloading https://files.pythonhosted.org/packages/c5/af/13b10d76bc0ff9188c9e5cd9f2726a5745029b76125938491f9abac5399d/azure_mgmt_recoveryservicesbackup-0.3.0-py2.py3-none-any.whl (568kB)
# Collecting azure-mgmt-hanaonazure~=0.1.1
#   Downloading https://files.pythonhosted.org/packages/f3/1b/50d300ae02158ab092f923132050b56c148f1b784c7b594d3275d4449769/azure_mgmt_hanaonazure-0.1.1-py2.py3-none-any.whl
# Collecting azure-mgmt-servicebus~=0.5.1
#   Downloading https://files.pythonhosted.org/packages/28/ad/9e90f8bab40a9682410e57ed08a799be113c5e470bec247b099038c6389e/azure_mgmt_servicebus-0.5.3-py2.py3-none-any.whl (112kB)
# Collecting azure-mgmt-compute~=4.0
#   Downloading https://files.pythonhosted.org/packages/0e/4d/7ac30585c567a8b9fe8294e0e956c6ef48665522ddf8f8c44bf38b700798/azure_mgmt_compute-4.6.2-py2.py3-none-any.whl (3.0MB)
# Collecting azure-mgmt-cosmosdb~=0.4.1
#   Downloading https://files.pythonhosted.org/packages/17/ed/d97a04c8c26e2432f2cf000b711daeb053e1cfbdb046bd5d070c941b4fcb/azure_mgmt_cosmosdb-0.4.1-py2.py3-none-any.whl (100kB)
# Collecting azure-mgmt-recoveryservices~=0.3.0
#   Downloading https://files.pythonhosted.org/packages/fd/7f/80327a27e03473101afb136e872279ad1386adf1bac14a58a9f839cd8352/azure_mgmt_recoveryservices-0.3.0-py2.py3-none-any.whl (70kB)
# Collecting azure-mgmt-relay~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/00/f7/f5c72bd19829cfaf9f070ec294c901ad7f98835ba9560fdad652afb1071f/azure_mgmt_relay-0.1.0-py2.py3-none-any.whl
# Collecting azure-mgmt-notificationhubs~=2.0
#   Downloading https://files.pythonhosted.org/packages/55/c0/62a0495583dfc44830f711be52cb4a4e116c2f72c89a19b90d654bdafc4a/azure_mgmt_notificationhubs-2.1.0-py2.py3-none-any.whl (76kB)
# Collecting azure-mgmt-eventhub~=2.1
#   Downloading https://files.pythonhosted.org/packages/5a/cb/3822bcfa815f894c86a27845ae4160c0169722598399234cd6f77bb82347/azure_mgmt_eventhub-2.6.0-py2.py3-none-any.whl (189kB)
# Collecting azure-mgmt-logic~=3.0
#   Downloading https://files.pythonhosted.org/packages/88/98/693c515e97043520f5cebf1ecae7bf198df100f5f9870b53d4be3bcaa5ce/azure_mgmt_logic-3.0.0-py2.py3-none-any.whl (303kB)
# Collecting azure-mgmt-sql~=0.9.1
#   Downloading https://files.pythonhosted.org/packages/c5/bb/219c76af961e9e6d1f5055d70c3cc06889b91375727a04367149c3aad640/azure_mgmt_sql-0.9.1-py2.py3-none-any.whl (485kB)
# Collecting azure-mgmt-redis~=5.0
#   Downloading https://files.pythonhosted.org/packages/90/a7/42342a984b2916972c5c5e24df94e3cd5e4377a8dc465a83415706d9be6f/azure_mgmt_redis-5.0.0-py2.py3-none-any.whl (43kB)
# Collecting azure-mgmt-network~=2.0
#   Downloading https://files.pythonhosted.org/packages/61/95/d63833e95406626256893a2f3ef4e5029a168330e3a27817a9f5597c0e6f/azure_mgmt_network-2.7.0-py2.py3-none-any.whl (11.4MB)
# Collecting azure-mgmt-powerbiembedded~=2.0
#   Downloading https://files.pythonhosted.org/packages/64/2b/5a69d118626a83055ce577fb6ba35c114e72f0273d0c4d943b909ee8d51e/azure_mgmt_powerbiembedded-2.0.0-py2.py3-none-any.whl
# Collecting azure-mgmt-trafficmanager~=0.50.0
#   Downloading https://files.pythonhosted.org/packages/ed/4f/c322d72dc92dde543471bc23f9ac0eb6b9d0dc2441bb5ce938250040e307/azure_mgmt_trafficmanager-0.50.0-py2.py3-none-any.whl (52kB)
# Collecting azure-mgmt-devtestlabs~=2.2
#   Downloading https://files.pythonhosted.org/packages/2f/93/a64abaede2fc6a52476af8ceab9cedb368c49e948d9385cbe7cd4ce5ffff/azure_mgmt_devtestlabs-2.2.0-py2.py3-none-any.whl (194kB)
# Collecting azure-mgmt-commerce~=1.0
#   Downloading https://files.pythonhosted.org/packages/7e/13/f421e77dd1fe3c9657a890f9c085f433fe422f54003ee03e631a8be5c4e7/azure_mgmt_commerce-1.0.1-py2.py3-none-any.whl
# Collecting azure-mgmt-cdn~=3.0
#   Downloading https://files.pythonhosted.org/packages/97/bf/c41e8985b4ffaaad2baaded1fb7b113433ae2d30d65c1a8c226e72284b72/azure_mgmt_cdn-3.1.0-py2.py3-none-any.whl (119kB)
# Collecting azure-mgmt-msi~=0.2.0
#   Downloading https://files.pythonhosted.org/packages/ae/95/b451721e38ca0feddce03ee3ce86158e208d0150253bd371207a8df4e9c5/azure_mgmt_msi-0.2.0-py2.py3-none-any.whl
# Collecting azure-mgmt-batchai~=2.0
#   Downloading https://files.pythonhosted.org/packages/d9/a5/ab796c2a490155c14f9ac4240724ca5c56723315d4dc753030712e6f2e80/azure_mgmt_batchai-2.0.0-py2.py3-none-any.whl (174kB)
# Collecting azure-mgmt-reservations~=0.2.1
#   Downloading https://files.pythonhosted.org/packages/a9/2b/e0edb8dbe85e447005cde508b869e564f58270f631219f036d8ab71184f9/azure_mgmt_reservations-0.2.1-py2.py3-none-any.whl (50kB)
# Collecting azure-mgmt-containerregistry~=2.1
#   Downloading https://files.pythonhosted.org/packages/97/70/8c2d0509db466678eba16fa2b0a539499f3b351b1f2993126ad843d5be13/azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718kB)
# Collecting azure-mgmt-web~=0.35.0
#   Downloading https://files.pythonhosted.org/packages/21/04/3f2622720664c972d927fd9e58c0066e998739b7891649207765be674126/azure_mgmt_web-0.35.0-py2.py3-none-any.whl (358kB)
# Collecting azure-mgmt-consumption~=2.0
#   Downloading https://files.pythonhosted.org/packages/11/f4/2db9557494dfb17ff3edeae5726981143a7baace17df3712b189e343bd8c/azure_mgmt_consumption-2.0.0-py2.py3-none-any.whl (46kB)
# Collecting azure-mgmt-devspaces~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/f4/d3/ff9c39578f24fb4bd158a882788c7795b177cf3f23ce7cf1d8b52066a64e/azure_mgmt_devspaces-0.1.0-py2.py3-none-any.whl
# Collecting azure-mgmt-subscription~=0.2.0
#   Downloading https://files.pythonhosted.org/packages/27/72/f63f72d9c27659f96aae287f7ba67c9ba2877213c2c10d8b797e0dee5059/azure_mgmt_subscription-0.2.0-py2.py3-none-any.whl (40kB)
# Collecting azure-mgmt-batch~=5.0
#   Downloading https://files.pythonhosted.org/packages/97/81/a9eb3fd2ab070159105b4cfe9640c24410ac8195286729d62bfdf871de94/azure_mgmt_batch-5.0.1-py2.py3-none-any.whl (87kB)
# Collecting azure-mgmt-monitor~=0.5.2
#   Downloading https://files.pythonhosted.org/packages/6a/3b/a8b95ee25f1c209ad82ad06de39f4efbfb9dc8a8dc5da5a7a48d7897bf3e/azure_mgmt_monitor-0.5.2-py2.py3-none-any.whl (247kB)
# Collecting azure-mgmt-dns~=2.0
#   Downloading https://files.pythonhosted.org/packages/c7/d7/0f986a64b06db93cf29b76f9a188f5778eb959624a00ed6aedc335ee58d2/azure_mgmt_dns-2.1.0-py2.py3-none-any.whl (134kB)
# Collecting azure-mgmt-managementpartner~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/9a/91/2bccd2bdca4158a7b6169538b25e22e0b4f8ff835754888aab45ffbd0448/azure_mgmt_managementpartner-0.1.1-py2.py3-none-any.whl
# Collecting azure-mgmt-policyinsights~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/19/84/7021951ae69572a19af0ff9cca1d2abf3542d35af38796656ded1be08358/azure_mgmt_policyinsights-0.1.0-py2.py3-none-any.whl (44kB)
# Collecting azure-mgmt-applicationinsights~=0.1.1
#   Downloading https://files.pythonhosted.org/packages/30/61/1d95a5ef3a9119a0d375d8670129375515de20e20409612e9671c99bd19f/azure_mgmt_applicationinsights-0.1.1-py2.py3-none-any.whl (42kB)
# Collecting azure-mgmt-containerservice~=4.2
#   Downloading https://files.pythonhosted.org/packages/5b/2f/0eba2dbd5d3f66c076a66b0020ccfe9c7e78534ac132afaa104c138680c1/azure_mgmt_containerservice-4.4.0-py2.py3-none-any.whl (206kB)
# Collecting azure-mgmt-datalake-analytics~=0.6.0
#   Downloading https://files.pythonhosted.org/packages/73/e7/5d909ef5812fc31f2871f3510ef43af93157ba51be03b6f798afba7a29d8/azure_mgmt_datalake_analytics-0.6.0-py2.py3-none-any.whl (288kB)
# Collecting azure-mgmt-containerinstance~=1.0
#   Downloading https://files.pythonhosted.org/packages/fd/d1/d770050f20ad81b80f7eb41f89e1a5d841cf74bf41c7e1ff137c46f28a1e/azure_mgmt_containerinstance-1.5.0-py2.py3-none-any.whl (96kB)
# Collecting azure-mgmt-managementgroups~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/f2/50/591adac2a6cd8d77cccd38bdf5d177ad6a2e95b9217daa9a60b5d86de5cd/azure_mgmt_managementgroups-0.1.0-py2.py3-none-any.whl (59kB)
# Collecting azure-mgmt-media~=1.0.0rc2
#   Downloading https://files.pythonhosted.org/packages/65/2e/6d9649bd5645ac32a179adfea5707f640fc51a57e493c27f0ab575789e85/azure_mgmt_media-1.0.0-py2.py3-none-any.whl (335kB)
# Collecting azure-mgmt-datalake-store~=0.5.0
#   Downloading https://files.pythonhosted.org/packages/ff/ac/5685cd06dc8b245bb6b894815764a14bd62245ba4579b45148682f510fdd/azure_mgmt_datalake_store-0.5.0-py2.py3-none-any.whl (88kB)
# Collecting azure-mgmt-resource~=2.0
#   Downloading https://files.pythonhosted.org/packages/1b/2d/9c3f2c9bf6e19f3efe4ddcaa946ea515d5229f4c0b387e224267e77fb73b/azure_mgmt_resource-2.2.0-py2.py3-none-any.whl (780kB)
# Collecting azure-mgmt-signalr~=0.1.0
#   Downloading https://files.pythonhosted.org/packages/10/32/379137548a4c6e4dfd15da6b1c476f2b1af52e8d7fe243fdac9ea2064427/azure_mgmt_signalr-0.1.1-py2.py3-none-any.whl (49kB)
# Collecting azure-mgmt-machinelearningcompute~=0.4.1
#   Downloading https://files.pythonhosted.org/packages/b4/9c/f8eb81b307df4465809b182f2fe44c288eeb41c0ab54f91b61ac554998a9/azure_mgmt_machinelearningcompute-0.4.1-py2.py3-none-any.whl
# Collecting cryptography
#   Downloading https://files.pythonhosted.org/packages/3c/04/686efee2dcdd25aecf357992e7d9362f443eb182ecd623f882bc9f7a6bba/cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7MB)
# Collecting azure-cosmosdb-nspkg>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/58/0d/1329b47e5386b0acf4e42ada2284851eff60ef3337a87e5b2dfedabbfcb1/azure_cosmosdb_nspkg-2.0.2-py2.py3-none-any.whl
# Collecting azure-nspkg>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/c4/0c/c562be95a9a2ed52454f598571cf300b1114d0db2aa27f5b8ed3bb9cd0c0/azure_nspkg-3.0.2-py3-none-any.whl
# Collecting msrest<2.0.0,>=0.4.29
#   Downloading https://files.pythonhosted.org/packages/56/f2/e2f9e4dc72884fff27e68ceaf027b9a3b80ba16f5757fc2916cb5d9117bd/msrest-0.6.13-py2.py3-none-any.whl (83kB)
# Collecting msrestazure<2.0.0,>=0.4.20
#   Downloading https://files.pythonhosted.org/packages/01/70/4abd575d876428e3892ca6b7acafb59b53cb9923fa6aec2cbbf173495ce1/msrestazure-0.6.3-py2.py3-none-any.whl (40kB)
# Collecting adal>=0.4.2
#   Downloading https://files.pythonhosted.org/packages/4f/b5/3ea9ae3d1096b9ff31e8f1846c47d49f3129a12464ac0a73b602de458298/adal-1.2.2-py2.py3-none-any.whl (53kB)
# Collecting cffi
#   Downloading https://files.pythonhosted.org/packages/f1/c7/72abda280893609e1ddfff90f8064568bd8bcb2c1770a9d5bb5edb2d1fea/cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399kB)
# Collecting traitlets>=4.2.1
#   Downloading https://files.pythonhosted.org/packages/ca/ab/872a23e29cec3cf2594af7e857f18b687ad21039c1f9b922fac5b9b142d5/traitlets-4.3.3-py2.py3-none-any.whl (75kB)
# Collecting Send2Trash
#   Downloading https://files.pythonhosted.org/packages/49/46/c3dc27481d1cc57b9385aff41c474ceb7714f7935b1247194adae45db714/Send2Trash-1.5.0-py3-none-any.whl
# Collecting terminado>=0.8.1
#   Downloading https://files.pythonhosted.org/packages/ff/96/1d9a2c23990aea8f8e0b5c3b6627d03196a73771a17a2d9860bbe9823ab6/terminado-0.8.3-py2.py3-none-any.whl
# Collecting jupyter-client>=5.3.4
#   Downloading https://files.pythonhosted.org/packages/34/0b/2ebddf775f558158ca8df23b35445fb15d4b1558a9e4a03bc7e75b13476e/jupyter_client-6.1.3-py3-none-any.whl (106kB)
# Collecting jupyter-core>=4.6.1
#   Downloading https://files.pythonhosted.org/packages/63/0d/df2d17cdf389cea83e2efa9a4d32f7d527ba78667e0153a8e676e957b2f7/jupyter_core-4.6.3-py2.py3-none-any.whl (83kB)
# Collecting nbconvert
#   Downloading https://files.pythonhosted.org/packages/79/6c/05a569e9f703d18aacb89b7ad6075b404e8a4afde2c26b73ca77bb644b14/nbconvert-5.6.1-py2.py3-none-any.whl (455kB)
# Collecting nbformat
#   Downloading https://files.pythonhosted.org/packages/d5/3c/251cfe5e3c9545ece107d342909ee3822d8cd9f3f11a591df37baeff2089/nbformat-5.0.6-py3-none-any.whl (170kB)
# Collecting pyzmq>=17
#   Downloading https://files.pythonhosted.org/packages/41/fa/e6e10410f01b03d10ab0705717d1246f63cdbbc0676140c78f0f757db332/pyzmq-19.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
# Collecting ipython-genutils
#   Downloading https://files.pythonhosted.org/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl
# Collecting ipykernel
#   Downloading https://files.pythonhosted.org/packages/ed/5d/cf47741fa80826f8edf435d9bcf0e84eef2d6d02953ff85e0563b3ab3f0b/ipykernel-5.2.1-py3-none-any.whl (118kB)
# Collecting pyasn1>=0.1.7
#   Downloading https://files.pythonhosted.org/packages/62/1e/a94a8d635fa3ce4cfc7f506003548d0a2447ae76fd5ca53932970fe3053f/pyasn1-0.4.8-py2.py3-none-any.whl (77kB)
# Collecting argparse>=1.4.0
#   Downloading https://files.pythonhosted.org/packages/f2/94/3af39d34be01a24a6e65433d19e107099374224905f1e0cc6bbe1fd22a2f/argparse-1.4.0-py2.py3-none-any.whl
# Collecting botocore<1.16.0,>=1.15.49
#   Downloading https://files.pythonhosted.org/packages/0f/2c/80605ef2f2800815dd2b0be0000295481b8e965b94541a3ed245c683c6f2/botocore-1.15.49-py2.py3-none-any.whl (6.2MB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/a3/43/1e939e1fcd87b827fe192d0c9fc25b48c5b3368902bfb913de7754b0dc03/jmespath-0.9.5-py2.py3-none-any.whl
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/69/79/e6afb3d8b0b4e96cefbdc690f741d7dd24547ff1f94240c997a26fa908d3/s3transfer-0.3.3-py2.py3-none-any.whl (69kB)
# Collecting uritemplate<4dev,>=3.0.0
#   Downloading https://files.pythonhosted.org/packages/bf/0c/60d82c077998feb631608dca3cc1fe19ac074e772bf0c24cf409b977b815/uritemplate-3.0.1-py2.py3-none-any.whl
# Collecting google-auth-httplib2>=0.0.3
#   Downloading https://files.pythonhosted.org/packages/33/49/c814d6d438b823441552198f096fcd0377fd6c88714dbed34f1d3c8c4389/google_auth_httplib2-0.0.3-py2.py3-none-any.whl
# Collecting ibm-cos-sdk-core==2.6.2
#   Downloading https://files.pythonhosted.org/packages/c1/f0/ebb57ccf2d3dc567988cea6a6ba778ebbf96bc4f40039866757dd97cb80a/ibm-cos-sdk-core-2.6.2.tar.gz (787kB)
# Collecting ibm-cos-sdk-s3transfer==2.6.2
#   Downloading https://files.pythonhosted.org/packages/c9/5e/11d12801a51cb74272d4f6072b4da5570d6739137e11f6573b6c043b3160/ibm-cos-sdk-s3transfer-2.6.2.tar.gz (131kB)
# Collecting oauthlib>=3.0.0
#   Downloading https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl (147kB)
# Collecting MarkupSafe>=0.23
#   Downloading https://files.pythonhosted.org/packages/b2/5f/23e0023be6bb885d00ffbefad2942bc51a620328ee910f64abe5a8d18dd1/MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading https://files.pythonhosted.org/packages/05/46/168fd780f594a4d61122f7f3dc0561686084319ad73b4febbf02ae8b32cf/googleapis-common-protos-1.51.0.tar.gz
# Collecting azure-mgmt-nspkg>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/b3/c2/af4b47845f27dc7d206ed4908b9e580f8bc94a4b2f3956a0d87c40719d90/azure_mgmt_nspkg-3.0.2-py3-none-any.whl
# Collecting azure-mgmt-datalake-nspkg>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/48/3d/c65a520d93448923a96784582a0deafaae096cb37b444ae5d63b57f0562d/azure_mgmt_datalake_nspkg-3.0.1-py3-none-any.whl
# Collecting isodate>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
# Collecting PyJWT>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Collecting pycparser
#   Downloading https://files.pythonhosted.org/packages/ae/e7/d9c3a176ca4b02024debf82342dab36efadfc5776f9c8db077e8f6e71821/pycparser-2.20-py2.py3-none-any.whl (112kB)
# Collecting decorator
#   Downloading https://files.pythonhosted.org/packages/ed/1b/72a1821152d07cf1d8b6fce298aeb06a7eb90f4d6d41acec9861e7cc6df0/decorator-4.4.2-py2.py3-none-any.whl
# Collecting ptyprocess; os_name != "nt"
#   Downloading https://files.pythonhosted.org/packages/d1/29/605c2cc68a9992d18dada28206eeada56ea4bd07a239669da41674648b6f/ptyprocess-0.6.0-py2.py3-none-any.whl
# Collecting testpath
#   Downloading https://files.pythonhosted.org/packages/1b/9e/1a170feaa54f22aeb5a5d16c9015e82234275a3c8ab630b552493f9cb8a9/testpath-0.4.4-py2.py3-none-any.whl (163kB)
# Collecting bleach
#   Downloading https://files.pythonhosted.org/packages/9a/1e/7d6cb3b27cd2c490558349ca5d5cc05b390b017da1c704cac807ac8bd9fb/bleach-3.1.5-py2.py3-none-any.whl (151kB)
# Collecting pandocfilters>=1.4.1
#   Downloading https://files.pythonhosted.org/packages/4c/ea/236e2584af67bb6df960832731a6e5325fd4441de001767da328c33368ce/pandocfilters-1.4.2.tar.gz
# Collecting defusedxml
#   Downloading https://files.pythonhosted.org/packages/06/74/9b387472866358ebc08732de3da6dc48e44b0aacd2ddaa5cb85ab7e986a2/defusedxml-0.6.0-py2.py3-none-any.whl
# Collecting entrypoints>=0.2.2
#   Downloading https://files.pythonhosted.org/packages/ac/c6/44694103f8c221443ee6b0041f69e2740d89a25641e62fb4f2ee568f2f9c/entrypoints-0.3-py2.py3-none-any.whl
# Collecting mistune<2,>=0.8.1
#   Downloading https://files.pythonhosted.org/packages/09/ec/4b43dae793655b7d8a25f76119624350b4d65eb663459eb9603d7f1f0345/mistune-0.8.4-py2.py3-none-any.whl
# Collecting pygments
#   Downloading https://files.pythonhosted.org/packages/2d/68/106af3ae51daf807e9cdcba6a90e518954eb8b70341cee52995540a53ead/Pygments-2.6.1-py3-none-any.whl (914kB)
# Collecting jsonschema!=2.5.0,>=2.4
#   Downloading https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl (56kB)
# Collecting ipython>=5.0.0
#   Downloading https://files.pythonhosted.org/packages/61/6f/69f1eec859ce48a86660529b166b6ea466f0f4ab98e4fc0807b835aa22c6/ipython-7.13.0-py3-none-any.whl (780kB)
# Collecting docutils<0.16,>=0.10
#   Downloading https://files.pythonhosted.org/packages/22/cd/a6aa959dca619918ccb55023b4cb151949c64d4d5d55b3f4ffd7eee0c6e8/docutils-0.15.2-py3-none-any.whl (547kB)
# Collecting packaging
#   Downloading https://files.pythonhosted.org/packages/62/0a/34641d2bf5c917c96db0ded85ae4da25b6cd922d6b794648d4e7e07c88e5/packaging-20.3-py2.py3-none-any.whl
# Collecting webencodings
#   Downloading https://files.pythonhosted.org/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl
# Collecting attrs>=17.4.0
#   Downloading https://files.pythonhosted.org/packages/a2/db/4313ab3be961f7a763066401fb77f7748373b6094076ae2bda2806988af6/attrs-19.3.0-py2.py3-none-any.whl
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading https://files.pythonhosted.org/packages/ad/e4/891bfcaf868ccabc619942f27940c77a8a4b45fd8367098955bb7e152fb1/importlib_metadata-1.6.0-py2.py3-none-any.whl
# Collecting pyrsistent>=0.14.0
#   Downloading https://files.pythonhosted.org/packages/9f/0d/cbca4d0bbc5671822a59f270e4ce3f2195f8a899c97d0d5abb81b191efb5/pyrsistent-0.16.0.tar.gz (108kB)
# Collecting jedi>=0.10
#   Downloading https://files.pythonhosted.org/packages/f3/3f/67f027e18c60a800875df1a0894a2436ce9053637fa39725766e937c0a71/jedi-0.17.0-py2.py3-none-any.whl (1.1MB)
# Collecting backcall
#   Downloading https://files.pythonhosted.org/packages/84/71/c8ca4f5bb1e08401b916c68003acf0a0655df935d74d93bf3f3364b310e0/backcall-0.1.0.tar.gz
# Collecting pickleshare
#   Downloading https://files.pythonhosted.org/packages/9a/41/220f49aaea88bc6fa6cba8d05ecf24676326156c23b991e80b3f2fc24c77/pickleshare-0.7.5-py2.py3-none-any.whl
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/e4/a7/81b39aa50e9284fe2cb21cc7fb7de7817b224172d42793fd57451d38842b/prompt_toolkit-3.0.5-py3-none-any.whl (351kB)
# Collecting pexpect; sys_platform != "win32"
#   Downloading https://files.pythonhosted.org/packages/39/7b/88dbb785881c28a102619d46423cb853b46dbccc70d3ac362d99773a78ce/pexpect-4.8.0-py2.py3-none-any.whl (59kB)
# Collecting pyparsing>=2.0.2
#   Downloading https://files.pythonhosted.org/packages/8a/bb/488841f56197b13700afd5658fc279a2025a39e22449b7cf29864669b15d/pyparsing-2.4.7-py2.py3-none-any.whl (67kB)
# Collecting zipp>=0.5
#   Downloading https://files.pythonhosted.org/packages/b2/34/bfcb43cc0ba81f527bc4f40ef41ba2ff4080e047acb0586b56b3d017ace4/zipp-3.1.0-py3-none-any.whl
# Collecting parso>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/b5/61/998cce9e7476de000d031874df26a18f67cb73448164fc44a98f0c55920b/parso-0.7.0-py2.py3-none-any.whl (100kB)
# Collecting wcwidth
#   Downloading https://files.pythonhosted.org/packages/f6/d5/1ecdac957e3ea12c1b319fcdee8b6917ffaff8b4644d673c4d72d2f20b49/wcwidth-0.1.9-py2.py3-none-any.whl
# Building wheels for collected packages: tornado, prometheus-client, jaeger-client, opentracing, Flask-OpenTracing, absl-py, termcolor, pyyaml, future, retrying, ibm-cos-sdk, threadloop, thrift, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer, googleapis-common-protos, pandocfilters, pyrsistent, backcall
#   Building wheel for tornado (setup.py): started
#   Building wheel for tornado (setup.py): finished with status 'done'
#   Created wheel for tornado: filename=tornado-6.0.4-cp36-cp36m-linux_x86_64.whl size=427972 sha256=dff7228cac3b95d2210a781835c798fa4a9e10b934b01f72be88b68c5275a5b7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/93/84/2f/409c7b2bb3afc3aa727f7ee8787975e0793f74d1165f4d0104
#   Building wheel for prometheus-client (setup.py): started
#   Building wheel for prometheus-client (setup.py): finished with status 'done'
#   Created wheel for prometheus-client: filename=prometheus_client-0.7.1-cp36-none-any.whl size=41402 sha256=6aa49dbe47249c16a5190ffa26401da274a665ae0930d3ebaaec1ad6f5454dda
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/1c/54/34/fd47cd9b308826cc4292b54449c1899a30251ef3b506bc91ea
#   Building wheel for jaeger-client (setup.py): started
#   Building wheel for jaeger-client (setup.py): finished with status 'done'
#   Created wheel for jaeger-client: filename=jaeger_client-4.1.0-cp36-none-any.whl size=64309 sha256=444701559e33a2817305afcd9dd5d0fe0021009c7793b9c39c534a5fdbf1c527
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/f2/84/7f/e89da3ee8ce35598d6382b6389fa2ada5d66acca2422537994
#   Building wheel for opentracing (setup.py): started
#   Building wheel for opentracing (setup.py): finished with status 'done'
# ...
#   Building wheel for absl-py (setup.py): started
#   Building wheel for absl-py (setup.py): finished with status 'done'
#   Created wheel for absl-py: filename=absl_py-0.9.0-cp36-none-any.whl size=121931 sha256=f2ab6db2764b1f592d5f8ed0db418a22cb0fd2eaea206f4cf1ceb570cbed2cbe
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/8e/28/49/fad4e7f0b9a1227708cbbee4487ac8558a7334849cb81c813d
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-cp36-none-any.whl size=4832 sha256=1b465771932eb0d37be0f7fd3d5c32c30065460dc6d76f6e01f47e8a9dad408a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/7c/06/54/bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
#   Building wheel for pyyaml (setup.py): started
#   Building wheel for pyyaml (setup.py): finished with status 'done'
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=480449 sha256=4c2d99a3a097f443744d8ffc286e1e36bb6eda2e874bba89b04980864305a6d4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-cp36-none-any.whl size=491057 sha256=2aceb3e7f9f005706839eba603e2ec4e8c00874b2c9e82465056321b6175d0a1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-cp36-none-any.whl size=11429 sha256=c3dfc6550fdf74d19507aa07266c60d86f5ca8df2e155dfc6c6402d6c5d66b97
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/d7/a9/33/acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c
#   Building wheel for ibm-cos-sdk (setup.py): started
#   Building wheel for ibm-cos-sdk (setup.py): finished with status 'done'
#   Created wheel for ibm-cos-sdk: filename=ibm_cos_sdk-2.6.2-py2.py3-none-any.whl size=72497 sha256=690fac881269a944fb6334ba9657ff5d42fd5dd6454806714eb5d7181d7ea1e0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/8c/4b/43/e3606c88bd7f0169a587d82ad79f5f826f91983106eec3e22b
#   Building wheel for threadloop (setup.py): started
#   Building wheel for threadloop (setup.py): finished with status 'done'
#   Created wheel for threadloop: filename=threadloop-1.0.2-cp36-none-any.whl size=3425 sha256=ee90df1ccc7c01f8963fafc94b9271de741ef3f00819c065d93b92f4c717a8b8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/d7/7a/30/d212623a4cd34f6cce400f8122b1b7af740d3440c68023d51f
#   Building wheel for thrift (setup.py): started
#   Building wheel for thrift (setup.py): finished with status 'done'
#   Created wheel for thrift: filename=thrift-0.13.0-cp36-cp36m-linux_x86_64.whl size=483936 sha256=81f001fe799320f80401710784845f58f9072fd431af3f56c88d57ec55467e19
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/02/a2/46/689ccfcf40155c23edc7cdbd9de488611c8fdf49ff34b1706e
#   Building wheel for ibm-cos-sdk-core (setup.py): started
#   Building wheel for ibm-cos-sdk-core (setup.py): finished with status 'done'
#   Created wheel for ibm-cos-sdk-core: filename=ibm_cos_sdk_core-2.6.2-py2.py3-none-any.whl size=462042 sha256=7207ec591d7656754a4abb081852ebcbaa28d7426426795c04fc4ae122fbf27a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/16/82/37/f124bfe619e72fc1c5f9abbd018bf2ee129f131bf2ede5ebcc
#   Building wheel for ibm-cos-sdk-s3transfer (setup.py): started
#   Building wheel for ibm-cos-sdk-s3transfer (setup.py): finished with status 'done'
#   Created wheel for ibm-cos-sdk-s3transfer: filename=ibm_cos_sdk_s3transfer-2.6.2-py2.py3-none-any.whl size=88602 sha256=45c8b5f548d81e91f59bf1b32e0a5df69e4c37fbb50c19a072619831cf2063cc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/49/c8/20/8139a0a66f56909d5e96bfa423067020e6b5736c3a5b53f51c
#   Building wheel for googleapis-common-protos (setup.py): started
#   Building wheel for googleapis-common-protos (setup.py): finished with status 'done'
#   Created wheel for googleapis-common-protos: filename=googleapis_common_protos-1.51.0-cp36-none-any.whl size=77593 sha256=e917b68ec22e0e0dc22beb59a19a469518c102d1b28c29a1c86c847b2655912e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/2c/f9/7f/6eb87e636072bf467e25348bbeb96849333e6a080dca78f706
#   Building wheel for pandocfilters (setup.py): started
#   Building wheel for pandocfilters (setup.py): finished with status 'done'
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.2-cp36-none-any.whl size=7856 sha256=56e5092b4a05cc0010a6adc350b8dd3f212ad522e4f06f399e93e25861b6397e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/39/01/56/f1b08a6275acc59e846fa4c1e1b65dbc1919f20157d9e66c20
#   Building wheel for pyrsistent (setup.py): started
#   Building wheel for pyrsistent (setup.py): finished with status 'done'
#   Created wheel for pyrsistent: filename=pyrsistent-0.16.0-cp36-cp36m-linux_x86_64.whl size=123217 sha256=69b533e46b3b89b49d3a248c06cc1508d0ead7abf664716aa8879ddf622030f0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/c2/85/ad/bc6d41e2c4b35c9fdfed48f0fcd411ffc4164e67755ddf9ebb
#   Building wheel for backcall (setup.py): started
#   Building wheel for backcall (setup.py): finished with status 'done'
#   Created wheel for backcall: filename=backcall-0.1.0-cp36-none-any.whl size=10411 sha256=aa98e59714ad4415d93575c65e83e35a808af6f95dc5d31d5e98107756ad12a3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btmvrwb_/wheels/98/b0/dd/29e28ff615af3dda4c67cab719dd51357597eabff926976b45
# Successfully built tornado prometheus-client jaeger-client opentracing Flask-OpenTracing absl-py termcolor pyyaml future retrying ibm-cos-sdk threadloop thrift ibm-cos-sdk-core ibm-cos-sdk-s3transfer googleapis-common-protos pandocfilters pyrsistent backcall
# ERROR: jaeger-client 4.1.0 has requirement tornado<6,>=4.3, but you'll have tornado 6.0.4 which is incompatible.
# ERROR: azure-mgmt 4.0.0 has requirement azure-mgmt-storage~=2.0, but you'll have azure-mgmt-storage 9.0.0 which is incompatible.
# ERROR: azure-storage-queue 1.4.0 has requirement azure-storage-common~=1.4, but you'll have azure-storage-common 2.1.0 which is incompatible.
# ERROR: azure-storage-file 1.4.0 has requirement azure-storage-common~=1.4, but you'll have azure-storage-common 2.1.0 which is incompatible.
# ERROR: azure 4.0.0 has requirement azure-storage-blob~=1.3, but you'll have azure-storage-blob 2.1.0 which is incompatible.
# ERROR: kubeflow-fairing 0.7.2 has requirement azure-storage-file>=2.1.0, but you'll have azure-storage-file 1.4.0 which is incompatible.
# ERROR: kubeflow-fairing 0.7.2 has requirement python-dateutil<=2.8.0,>=2.1, but you'll have python-dateutil 2.8.1 which is incompatible.
# ERROR: kubeflow-fairing 0.7.2 has requirement requests<2.23,>=2.21.0, but you'll have requests 2.23.0 which is incompatible.
# ERROR: kubeflow-fairing 0.7.2 has requirement urllib3==1.24.2, but you'll have urllib3 1.25.9 which is incompatible.
# Installing collected packages: cloudpickle, six, python-dateutil, pytz, numpy, pandas, scipy, joblib, scikit-learn, imbalanced-learn, imblearn, prometheus-client, urllib3, chardet, idna, certifi, requests, tornado, threadloop, thrift, opentracing, jaeger-client, pyyaml, pyaml, configparser, minio, grpcio, grpcio-opentracing, gunicorn, protobuf, azure-common, pycparser, cffi, cryptography, azure-storage-common, azure-storage-blob, flatbuffers, click, MarkupSafe, Jinja2, Werkzeug, itsdangerous, Flask, Flask-cors, redis, Flask-OpenTracing, seldon-core, keras-preprocessing, h5py, keras-applications, astor, mock, absl-py, tensorflow-estimator, gast, markdown, tensorboard, termcolor, tensorflow, keras, cachetools, pyasn1, rsa, pyasn1-modules, google-auth, googleapis-common-protos, google-api-core, google-cloud-core, google-resumable-media, google-cloud-storage, websocket-client, oauthlib, requests-oauthlib, kubernetes, table-logger, kubeflow-tfjob, azure-nspkg, azure-mgmt-nspkg, PyJWT, adal, isodate, msrest, msrest
# azure, azure-mgmt-authorization, azure-mgmt-cognitiveservices, azure-mgmt-iothubprovisioningservices, azure-mgmt-advisor, azure-mgmt-search, azure-mgmt-loganalytics, azure-mgmt-marketplaceordering, azure-mgmt-billing, azure-mgmt-iotcentral, azure-mgmt-scheduler, azure-mgmt-keyvault, azure-mgmt-eventgrid, azure-mgmt-maps, azure-mgmt-servicefabric, azure-mgmt-rdbms, azure-mgmt-iothub, azure-mgmt-datafactory, azure-mgmt-datamigration, azure-mgmt-recoveryservicesbackup, azure-mgmt-hanaonazure, azure-mgmt-servicebus, azure-mgmt-compute, azure-mgmt-cosmosdb, azure-mgmt-recoveryservices, azure-mgmt-relay, azure-mgmt-notificationhubs, azure-mgmt-eventhub, azure-mgmt-logic, azure-mgmt-sql, azure-mgmt-redis, azure-mgmt-network, azure-mgmt-powerbiembedded, azure-mgmt-trafficmanager, azure-mgmt-devtestlabs, azure-mgmt-commerce, azure-mgmt-cdn, azure-mgmt-msi, azure-mgmt-batchai, azure-mgmt-reservations, azure-mgmt-containerregistry, azure-mgmt-web, azure-mgmt-consumption, azure-mgmt-devspaces, azure-mgmt-storage, azure-m
# gmt-subscription, azure-mgmt-batch, azure-mgmt-monitor, azure-mgmt-dns, azure-mgmt-managementpartner, azure-mgmt-policyinsights, azure-mgmt-applicationinsights, azure-mgmt-containerservice, azure-mgmt-datalake-nspkg, azure-mgmt-datalake-analytics, azure-mgmt-containerinstance, azure-mgmt-managementgroups, azure-mgmt-media, azure-mgmt-datalake-store, azure-mgmt-resource, azure-mgmt-signalr, azure-mgmt-machinelearningcompute, azure-mgmt, azure-cosmosdb-nspkg, azure-cosmosdb-table, azure-loganalytics, azure-servicefabric, azure-storage-queue, azure-servicebus, azure-batch, azure-datalake-store, azure-eventgrid, azure-keyvault, azure-storage-file, azure-servicemanagement-legacy, azure-applicationinsights, azure-graphrbac, azure, ipython-genutils, decorator, traitlets, Send2Trash, ptyprocess, terminado, pyzmq, jupyter-core, jupyter-client, testpath, pyparsing, packaging, webencodings, bleach, pandocfilters, attrs, zipp, importlib-metadata, pyrsistent, jsonschema, nbformat, defusedxml, entrypoints, mistune, pygment
# s, nbconvert, parso, jedi, backcall, pickleshare, wcwidth, prompt-toolkit, pexpect, ipython, ipykernel, notebook, future, httplib2, oauth2client, kubeflow-pytorchjob, argparse, kfserving, google-cloud-logging, retrying, docutils, jmespath, botocore, s3transfer, boto3, docker, uritemplate, google-auth-httplib2, google-api-python-client, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer, ibm-cos-sdk, kubeflow-fairing
# Successfully installed Flask-1.1.2 Flask-OpenTracing-1.1.0 Flask-cors-3.0.8 Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 Send2Trash-1.5.0 Werkzeug-1.0.1 absl-py-0.9.0 adal-1.2.2 argparse-1.4.0 astor-0.8.1 attrs-19.3.0 azure-4.0.0 azure-applicationinsights-0.1.0 azure-batch-4.1.3 azure-common-1.1.25 azure-cosmosdb-nspkg-2.0.2 azure-cosmosdb-table-1.0.6 azure-datalake-store-0.0.48 azure-eventgrid-1.3.0 azure-graphrbac-0.40.0 azure-keyvault-1.1.0 azure-loganalytics-0.1.0 azure-mgmt-4.0.0 azure-mgmt-advisor-1.0.1 azure-mgmt-applicationinsights-0.1.1 azure-mgmt-authorization-0.50.0 azure-mgmt-batch-5.0.1 azure-mgmt-batchai-2.0.0 azure-mgmt-billing-0.2.0 azure-mgmt-cdn-3.1.0 azure-mgmt-cognitiveservices-3.0.0 azure-mgmt-commerce-1.0.1 azure-mgmt-compute-4.6.2 azure-mgmt-consumption-2.0.0 azure-mgmt-containerinstance-1.5.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-containerservice-4.4.0 azure-mgmt-cosmosdb-0.4.1 azure-mgmt-datafactory-0.6.0 azure-mgmt-datalake-analytics-0.6.0 azure-mgmt-datalake-nspkg-3.0.1 azure-
# mgmt-datalake-store-0.5.0 azure-mgmt-datamigration-1.0.0 azure-mgmt-devspaces-0.1.0 azure-mgmt-devtestlabs-2.2.0 azure-mgmt-dns-2.1.0 azure-mgmt-eventgrid-1.0.0 azure-mgmt-eventhub-2.6.0 azure-mgmt-hanaonazure-0.1.1 azure-mgmt-iotcentral-0.1.0 azure-mgmt-iothub-0.5.0 azure-mgmt-iothubprovisioningservices-0.2.0 azure-mgmt-keyvault-1.1.0 azure-mgmt-loganalytics-0.2.0 azure-mgmt-logic-3.0.0 azure-mgmt-machinelearningcompute-0.4.1 azure-mgmt-managementgroups-0.1.0 azure-mgmt-managementpartner-0.1.1 azure-mgmt-maps-0.1.0 azure-mgmt-marketplaceordering-0.1.0 azure-mgmt-media-1.0.0 azure-mgmt-monitor-0.5.2 azure-mgmt-msi-0.2.0 azure-mgmt-network-2.7.0 azure-mgmt-notificationhubs-2.1.0 azure-mgmt-nspkg-3.0.2 azure-mgmt-policyinsights-0.1.0 azure-mgmt-powerbiembedded-2.0.0 azure-mgmt-rdbms-1.9.0 azure-mgmt-recoveryservices-0.3.0 azure-mgmt-recoveryservicesbackup-0.3.0 azure-mgmt-redis-5.0.0 azure-mgmt-relay-0.1.0 azure-mgmt-reservations-0.2.1 azure-mgmt-resource-2.2.0 azure-mgmt-scheduler-2.0.0 azure-mgmt-search-2.1.0
#  azure-mgmt-servicebus-0.5.3 azure-mgmt-servicefabric-0.2.0 azure-mgmt-signalr-0.1.1 azure-mgmt-sql-0.9.1 azure-mgmt-storage-9.0.0 azure-mgmt-subscription-0.2.0 azure-mgmt-trafficmanager-0.50.0 azure-mgmt-web-0.35.0 azure-nspkg-3.0.2 azure-servicebus-0.21.1 azure-servicefabric-6.3.0.0 azure-servicemanagement-legacy-0.20.6 azure-storage-blob-2.1.0 azure-storage-common-2.1.0 azure-storage-file-1.4.0 azure-storage-queue-1.4.0 backcall-0.1.0 bleach-3.1.5 boto3-1.12.49 botocore-1.15.49 cachetools-4.1.0 certifi-2020.4.5.1 cffi-1.14.0 chardet-3.0.4 click-7.1.2 cloudpickle-1.1.1 configparser-5.0.0 cryptography-2.9.2 decorator-4.4.2 defusedxml-0.6.0 docker-4.2.0 docutils-0.15.2 entrypoints-0.3 flatbuffers-1.12 future-0.18.2 gast-0.3.3 google-api-core-1.17.0 google-api-python-client-1.8.2 google-auth-1.14.1 google-auth-httplib2-0.0.3 google-cloud-core-1.3.0 google-cloud-logging-1.15.0 google-cloud-storage-1.28.0 google-resumable-media-0.5.0 googleapis-common-protos-1.51.0 grpcio-1.28.1 grpcio-opentracing-1.1.4 gunicorn
# -20.0.4 h5py-2.10.0 httplib2-0.17.3 ibm-cos-sdk-2.6.2 ibm-cos-sdk-core-2.6.2 ibm-cos-sdk-s3transfer-2.6.2 idna-2.9 imbalanced-learn-0.6.2 imblearn-0.0 importlib-metadata-1.6.0 ipykernel-5.2.1 ipython-7.13.0 ipython-genutils-0.2.0 isodate-0.6.0 itsdangerous-1.1.0 jaeger-client-4.1.0 jedi-0.17.0 jmespath-0.9.5 joblib-0.14.1 jsonschema-3.2.0 jupyter-client-6.1.3 jupyter-core-4.6.3 keras-2.2.4 keras-applications-1.0.8 keras-preprocessing-1.1.0 kfserving-0.3.0.1 kubeflow-fairing-0.7.2 kubeflow-pytorchjob-0.1.3 kubeflow-tfjob-0.1.3 kubernetes-10.0.1 markdown-3.2.1 minio-5.0.10 mistune-0.8.4 mock-4.0.2 msrest-0.6.13 msrestazure-0.6.3 nbconvert-5.6.1 nbformat-5.0.6 notebook-6.0.3 numpy-1.18.3 oauth2client-4.1.3 oauthlib-3.1.0 opentracing-2.2.0 packaging-20.3 pandas-1.0.3 pandocfilters-1.4.2 parso-0.7.0 pexpect-4.8.0 pickleshare-0.7.5 prometheus-client-0.7.1 prompt-toolkit-3.0.5 protobuf-3.11.3 ptyprocess-0.6.0 pyaml-19.12.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.20 pygments-2.6.1 pyparsing-2.4.7 pyrsistent-0.1
# 6.0 python-dateutil-2.8.1 pytz-2020.1 pyyaml-5.3.1 pyzmq-19.0.0 redis-3.5.0 requests-2.23.0 requests-oauthlib-1.3.0 retrying-1.3.3 rsa-4.0 s3transfer-0.3.3 scikit-learn-0.22.2 scipy-1.4.1 seldon-core-1.1.0 six-1.14.0 table-logger-0.3.6 tensorboard-1.13.1 tensorflow-1.13.1 tensorflow-estimator-1.13.0 termcolor-1.1.0 terminado-0.8.3 testpath-0.4.4 threadloop-1.0.2 thrift-0.13.0 tornado-6.0.4 traitlets-4.3.3 uritemplate-3.0.1 urllib3-1.25.9 wcwidth-0.1.9 webencodings-0.5.1 websocket-client-0.57.0 zipp-3.1.0
# WARNING: You are using pip version 19.3.1; however, version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# INFO[0115] Taking snapshot of full filesystem...
# INFO[0174] Using files from context: [/kaniko/buildcontext/app]
# INFO[0175] COPY /app/ /app/
# INFO[0175] Taking snapshot of files...
# Deploying the endpoint.
# Cluster endpoint: http://fairing-service-pxnbw.anonymous.svc.cluster.local:5000/predict
# Prediction endpoint: http://fairing-service-pxnbw.anonymous.svc.cluster.local:5000/predict

# %% [markdown]
# ## Wait for  prediction pod ready state

# %%
# !kubectl get deploy -l fairing-deployer=serving -n anonymous
# Out:
# NAME                     READY   UP-TO-DATE   AVAILABLE   AGE
# fairing-deployer-xrz2m   1/1     1            1           88s

# %% [markdown]
# ##  Get prediction endpoint

# %%
endpoint.url
# Out:
# 'http://fairing-service-pxnbw.anonymous.svc.cluster.local:5000/predict'

# %% [markdown]
# ## Call the prediction endpoint
# Use the endpoint from previous cell

# %%
! curl -v http://fairing-service-pxnbw.anonymous.svc.cluster.local:5000/predict -H "Content-Type: application/x-www-form-urlencoded" -d 'json={"data":{"ndarray":[0.000000, 0.000000, 0.000000, 0.000000, 0.000005, 0.000000, 0.000000, 0.000000, 0.000000, 0.000004]}}'
# Out:
# *   Trying 10.109.244.138...
# * TCP_NODELAY set
# * Connected to fairing-service-pxnbw.anonymous.svc.cluster.local (10.109.244.138) port 5000 (#0)
# > POST /predict HTTP/1.1
# > Host: fairing-service-pxnbw.anonymous.svc.cluster.local:5000
# > User-Agent: curl/7.58.0
# > Accept: */*
# > Content-Type: application/x-www-form-urlencoded
# > Content-Length: 126
# >
# * upload completely sent off: 126 out of 126 bytes
# * HTTP 1.0, assume close after body
# < HTTP/1.0 200 OK
# < Content-Type: application/json
# < Content-Length: 53
# < Access-Control-Allow-Origin: *
# < Server: Werkzeug/1.0.1 Python/3.6.9
# < Date: Thu, 30 Apr 2020 07:59:19 GMT
# <
# {"data":{"names":["t:0"],"ndarray":[[0]]},"meta":{}}
# * Closing connection 0

# %% [markdown]
# ## Clean up the prediction endpoint
# Delete the prediction endpoint created by this notebook.

# %%
endpoint.delete()
# Out:
# Deleting the endpoint.
# Deleted service: anonymous/fairing-service-pxnbw
# Deleted deployment: anonymous/fairing-deployer-xrz2m

# %% [markdown]
# ## Clean up TFjob

# %%
TFJobClient().delete(tfjob_name, namespace=namespace)
# Out:
# {'kind': 'Status',
#  'apiVersion': 'v1',
#  'metadata': {},
#  'status': 'Success',
#  'details': {'name': 'network-fairing-tfjob',
#   'group': 'kubeflow.org',
#   'kind': 'tfjobs',
#   'uid': '294d27c9-acfa-4767-baf1-99261bdcf7c3'}}

# %% [markdown]
# ## Delete config.json and requirements.txt

# %%
# !rm -rf config.json requirements.txt
if device_type=="gpu":
    # !sed -i "s/gpu-py3/py3/g" Dockerfile
    # !cat Dockerfile
# Out:
# FROM tensorflow/tensorflow:1.14.0-py3
# RUN pip install -U scikit-learn
# RUN pip install keras pandas imblearn
# ADD network_model.py  /opt/network_model.py
# ADD Network_Traffic.csv /opt/Network_Traffic.csv
# RUN chmod +x /opt/network_model.py  /opt/Network_Traffic.csv
# WORKDIR /opt/
# RUN mkdir -p /mnt/Model_Network
# CMD python network_model.py
